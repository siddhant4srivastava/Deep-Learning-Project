# %%
import os
os.environ["KERAS_BACKEND"]="tensorflow"
import re
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras import layers
from keras.applications import efficientnet
from keras.layers import TextVectorization
keras.utils.set_random_seed(111)

# %%
# !wget https://www.dropbox.com/sh/q4dehgdtbo0b6vt/AABFoMwAxqEQWQnl_xQYY2fsa?dl=0
# Out:
# --2024-11-18 06:51:02--  https://www.dropbox.com/sh/q4dehgdtbo0b6vt/AABFoMwAxqEQWQnl_xQYY2fsa?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fo/bzncnlk9ufjde4t7w0q4k/AHQ8GDVQ5ANUg7oNBfvgcdE?rlkey=cdg8cc8hdfsazsj6rmvpqwrd1&dl=0 [following]
# --2024-11-18 06:51:02--  https://www.dropbox.com/scl/fo/bzncnlk9ufjde4t7w0q4k/AHQ8GDVQ5ANUg7oNBfvgcdE?rlkey=cdg8cc8hdfsazsj6rmvpqwrd1&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc42b8a66ed68681e5a9102bc8b0.dl.dropboxusercontent.com/zip_download_get/CB-UOlcFDoJpee5iJsgeb-ze6luD4O9gQulS2IBJE8DBVJsxjGSRAjgcZcYEMk9Slggupp8zt77OMAfesGScxOBMehjyCHfbaYHwxoYsf3zRmA# [following]
# --2024-11-18 06:51:09--  https://uc42b8a66ed68681e5a9102bc8b0.dl.dropboxusercontent.com/zip_download_get/CB-UOlcFDoJpee5iJsgeb-ze6luD4O9gQulS2IBJE8DBVJsxjGSRAjgcZcYEMk9Slggupp8zt77OMAfesGScxOBMehjyCHfbaYHwxoYsf3zRmA
# Resolving uc42b8a66ed68681e5a9102bc8b0.dl.dropboxusercontent.com (uc42b8a66ed68681e5a9102bc8b0.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc42b8a66ed68681e5a9102bc8b0.dl.dropboxusercontent.com (uc42b8a66ed68681e5a9102bc8b0.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1126431322 (1.0G) [application/zip]
# Saving to: ‘AABFoMwAxqEQWQnl_xQYY2fsa?dl=0’
#
# AABFoMwAxqEQWQnl_xQ 100%[===================>]   1.05G  19.8MB/s    in 89s
#
# 2024-11-18 06:52:41 (12.1 MB/s) - ‘AABFoMwAxqEQWQnl_xQYY2fsa?dl=0’ saved [1126431322/1126431322]

# %%
# !unzip /content/AABFoMwAxqEQWQnl_xQYY2fsa?dl=0
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: Flicker8k_Dataset/2083778090_3aecaa11cc.jpg
#  extracting: Flicker8k_Dataset/2089555297_95cf001fa7.jpg
#  extracting: Flicker8k_Dataset/2195887578_3ba2f29b48.jpg
#  extracting: Flicker8k_Dataset/2230067846_74046b89d3.jpg
#  extracting: Flicker8k_Dataset/2264316030_600e55748d.jpg
#  extracting: Flicker8k_Dataset/2271671533_7538ccd556.jpg
#  extracting: Flicker8k_Dataset/2420730259_86e7f8a815.jpg
#  extracting: Flicker8k_Dataset/2602085456_d1beebcb29.jpg
#  extracting: Flicker8k_Dataset/2687672606_275169c35d.jpg
#  extracting: Flicker8k_Dataset/2750867389_4b815f793a.jpg
#  extracting: Flicker8k_Dataset/2751694538_fffa3d307d.jpg
#  extracting: Flicker8k_Dataset/2809793070_1a3387cd6e.jpg
#  extracting: Flicker8k_Dataset/2871962580_b85ce502ba.jpg
#  extracting: Flicker8k_Dataset/2929272606_2a5923b38e.jpg
#  extracting: Flicker8k_Dataset/3015898903_70bebb8903.jpg
#  extracting: Flicker8k_Dataset/3018847610_0bf4d7e43d.jpg
#  extracting: Flicker8k_Dataset/3172384527_b107385a20.jpg
#  extracting: Flicker8k_Dataset/3246804978_ea2c9e56f2.jpg
#  extracting: Flicker8k_Dataset/3268191118_ba25fabab6.jpg
#  extracting: Flicker8k_Dataset/3288173388_03bc2a844d.jpg
#  extracting: Flicker8k_Dataset/3451523035_b61d79f6a8.jpg
#  extracting: Flicker8k_Dataset/3502563726_30d1ce29c8.jpg
#  extracting: Flicker8k_Dataset/3534183988_3763593dfb.jpg
#  extracting: Flicker8k_Dataset/3535768334_a3924bcccd.jpg
#  extracting: Flicker8k_Dataset/3602676311_824b2c04ba.jpg
#  extracting: Flicker8k_Dataset/3627076769_3b71e73018.jpg
#  extracting: Flicker8k_Dataset/3722572342_6904d11d52.jpg
#  extracting: Flicker8k_Dataset/1077931201_1e0bb83105.jpg
#  extracting: Flicker8k_Dataset/1308472581_9961782889.jpg
#  extracting: Flicker8k_Dataset/1332722096_1e3de8ae70.jpg
#  extracting: Flicker8k_Dataset/1427391496_ea512cbe7f.jpg
#  extracting: Flicker8k_Dataset/1776981714_5b224d0f7a.jpg
#  extracting: Flicker8k_Dataset/1808007704_ee8a93abb4.jpg
#  extracting: Flicker8k_Dataset/2043427251_83b746da8e.jpg
#  extracting: Flicker8k_Dataset/2238019823_79318d1f11.jpg
#  extracting: Flicker8k_Dataset/2273871383_1ddb3562ea.jpg
#  extracting: Flicker8k_Dataset/2423292784_166ee54e0b.jpg
#  extracting: Flicker8k_Dataset/2629346153_155ba73ae9.jpg
#  extracting: Flicker8k_Dataset/2664102751_d5a737a566.jpg
#  extracting: Flicker8k_Dataset/2718495608_d8533e3ac5.jpg
#  extracting: Flicker8k_Dataset/2747714500_49476225c6.jpg
#  extracting: Flicker8k_Dataset/2834752476_3177e617f1.jpg
#  extracting: Flicker8k_Dataset/2869765795_21a398cb24.jpg
#  extracting: Flicker8k_Dataset/2872963574_52ab5182cb.jpg
#  extracting: Flicker8k_Dataset/2956413620_d59de03a06.jpg
#  extracting: Flicker8k_Dataset/3006217970_90b42e6b27.jpg
#  extracting: Flicker8k_Dataset/3048211972_db71d104c2.jpg
#  extracting: Flicker8k_Dataset/3109124656_626b596d5e.jpg
#  extracting: Flicker8k_Dataset/3203453897_6317aac6ff.jpg
#  extracting: Flicker8k_Dataset/3211581957_df2f7e2236.jpg
#  extracting: Flicker8k_Dataset/3245460937_2710a82709.jpg
#  extracting: Flicker8k_Dataset/3263741906_6e4508d1c8.jpg
#  extracting: Flicker8k_Dataset/3276448136_0d9f5069c5.jpg
#  extracting: Flicker8k_Dataset/3323528927_7b21081271.jpg
#  extracting: Flicker8k_Dataset/3341477531_4e37450f35.jpg
#  extracting: Flicker8k_Dataset/3363750526_efcedc47a9.jpg
#  extracting: Flicker8k_Dataset/3373481779_511937e09d.jpg
#  extracting: Flicker8k_Dataset/3420323191_d66e003264.jpg
#  extracting: Flicker8k_Dataset/3429194423_98e911a101.jpg
#  extracting: Flicker8k_Dataset/3459858555_c3f0087a72.jpg
#  extracting: Flicker8k_Dataset/3567604049_da9e1be4ba.jpg
#  extracting: Flicker8k_Dataset/3595412126_4020d4643b.jpg
#  extracting: Flicker8k_Dataset/3720210639_18bb34e475.jpg
#  extracting: Flicker8k_Dataset/1042590306_95dea0916c.jpg
#  extracting: Flicker8k_Dataset/1215334959_b1970965f7.jpg
#  extracting: Flicker8k_Dataset/1342766791_1e72f92455.jpg
#  extracting: Flicker8k_Dataset/1732217138_aa0199ef87.jpg
#  extracting: Flicker8k_Dataset/1884065356_c6c34b4568.jpg
#  extracting: Flicker8k_Dataset/2045109977_b00ec93491.jpg
#  extracting: Flicker8k_Dataset/2095007523_591f255708.jpg
#  extracting: Flicker8k_Dataset/2609900643_c07bcb0bae.jpg
#  extracting: Flicker8k_Dataset/2618866067_07cbc83dc5.jpg
#  extracting: Flicker8k_Dataset/2621415349_ef1a7e73be.jpg
#  extracting: Flicker8k_Dataset/2866696346_4dcccbd3a5.jpg
#  extracting: Flicker8k_Dataset/2906054175_e33af79522.jpg
#  extracting: Flicker8k_Dataset/3084711346_fda0f5a3e6.jpg
#  extracting: Flicker8k_Dataset/3092370204_029b6bc10a.jpg
#  extracting: Flicker8k_Dataset/3139238055_2817a0c7d8.jpg
#  extracting: Flicker8k_Dataset/3169276423_6918dd4da1.jpg
#  extracting: Flicker8k_Dataset/3204354161_caf89ec784.jpg
#  extracting: Flicker8k_Dataset/3211556865_d1d9becf69.jpg
#  extracting: Flicker8k_Dataset/3222055946_45f7293bb2.jpg
#  extracting: Flicker8k_Dataset/3293018193_e4e0c8db7c.jpg
#  extracting: Flicker8k_Dataset/3324746155_71e14f60ce.jpg
#  extracting: Flicker8k_Dataset/3359530430_249f51972c.jpg
#  extracting: Flicker8k_Dataset/3367758711_a8c09607ac.jpg
#  extracting: Flicker8k_Dataset/3447876218_4ccf42d7a0.jpg
#  extracting: Flicker8k_Dataset/3466891862_9afde75568.jpg
#  extracting: Flicker8k_Dataset/3497236690_a48bf7ac42.jpg
#  extracting: Flicker8k_Dataset/3595216998_0a19efebd0.jpg
#  extracting: Flicker8k_Dataset/3673970325_4e025069e9.jpg
#  extracting: Flicker8k_Dataset/3685372942_6ae935b34e.jpg
#  extracting: Flicker8k_Dataset/1305564994_00513f9a5b.jpg
#  extracting: Flicker8k_Dataset/1306145560_1e37081b91.jpg
#  extracting: Flicker8k_Dataset/1433577867_39a1510c43.jpg
#  extracting: Flicker8k_Dataset/1436760519_8d6101a0ed.jpg
#  extracting: Flicker8k_Dataset/2185793891_5a5e903ca6.jpg
#  extracting: Flicker8k_Dataset/2255685792_f70474c6db.jpg
#  extracting: Flicker8k_Dataset/2261962622_e9318a95eb.jpg
#  extracting: Flicker8k_Dataset/2332540384_4cf26406a9.jpg
#  extracting: Flicker8k_Dataset/2442243868_abe8f74fb4.jpg
#  extracting: Flicker8k_Dataset/2597308074_acacc12e1b.jpg
#  extracting: Flicker8k_Dataset/2753506871_dc38e7d153.jpg
#  extracting: Flicker8k_Dataset/3006095077_1992b677f8.jpg
#  extracting: Flicker8k_Dataset/3120189281_1938460e85.jpg
#  extracting: Flicker8k_Dataset/3167379087_927ff05a35.jpg
#  extracting: Flicker8k_Dataset/3250589803_3f440ba781.jpg
#  extracting: Flicker8k_Dataset/3285214689_f0219e9671.jpg
#  extracting: Flicker8k_Dataset/3287963317_186491ee78.jpg
#  extracting: Flicker8k_Dataset/3361210233_962d630ec5.jpg
#  extracting: Flicker8k_Dataset/3368207495_1e2dbd6d3f.jpg
#  extracting: Flicker8k_Dataset/3379839396_0cd84b55f1.jpg
#  extracting: Flicker8k_Dataset/3385956569_a849218e34.jpg
#  extracting: Flicker8k_Dataset/3396036947_0af6c3aab7.jpg
#  extracting: Flicker8k_Dataset/3397228832_8ce5b1c26f.jpg
#  extracting: Flicker8k_Dataset/3425127583_611200619a.jpg
#  extracting: Flicker8k_Dataset/3442978981_53bf1f45f3.jpg
#  extracting: Flicker8k_Dataset/3477315700_52a4d740a5.jpg
#  extracting: Flicker8k_Dataset/3482668767_66004ce736.jpg
#  extracting: Flicker8k_Dataset/3494394662_3edfd4a34c.jpg
#  extracting: Flicker8k_Dataset/3496983524_b21ecdb0c7.jpg
#  extracting: Flicker8k_Dataset/3543294190_0037c59607.jpg
#  extracting: Flicker8k_Dataset/3562282690_cd2a95fe9e.jpg
#  extracting: Flicker8k_Dataset/3621652774_fd9634bd5b.jpg
#  extracting: Flicker8k_Dataset/3705430840_e108de78bf.jpg
#  extracting: Flicker8k_Dataset/1067790824_f3cc97239b.jpg
#  extracting: Flicker8k_Dataset/1415591512_a84644750c.jpg
#  extracting: Flicker8k_Dataset/1449692616_60507875fb.jpg
#  extracting: Flicker8k_Dataset/1468103286_96a6e07029.jpg
#  extracting: Flicker8k_Dataset/2114355355_9d7e2d8178.jpg
#  extracting: Flicker8k_Dataset/2172493537_128bc8b187.jpg
#  extracting: Flicker8k_Dataset/2194494220_bb2178832c.jpg
#  extracting: Flicker8k_Dataset/2396100671_3a9d67f03d.jpg
#  extracting: Flicker8k_Dataset/2425262733_afe0718276.jpg
#  extracting: Flicker8k_Dataset/2458033289_f0616879df.jpg
#  extracting: Flicker8k_Dataset/2467856402_0490413d38.jpg
#  extracting: Flicker8k_Dataset/2533642917_a5eace85e6.jpg
#  extracting: Flicker8k_Dataset/2542662402_d781dd7f7c.jpg
#  extracting: Flicker8k_Dataset/2641770481_c98465ff35.jpg
#  extracting: Flicker8k_Dataset/2684322797_85406f571d.jpg
#  extracting: Flicker8k_Dataset/2760715910_87c7bdeb87.jpg
#  extracting: Flicker8k_Dataset/2860400846_2c1026a573.jpg
#  extracting: Flicker8k_Dataset/2867699650_e6ddb540de.jpg
#  extracting: Flicker8k_Dataset/3106026005_473a7b1c8c.jpg
#  extracting: Flicker8k_Dataset/3133825703_359a0c414d.jpg
#  extracting: Flicker8k_Dataset/3139895886_5a6d495b13.jpg
#  extracting: Flicker8k_Dataset/3211210739_3dea005fde.jpg
#  extracting: Flicker8k_Dataset/3249891130_b241591e89.jpg
#  extracting: Flicker8k_Dataset/3269380710_9161b0bd00.jpg
#  extracting: Flicker8k_Dataset/3308997740_91765ecdcc.jpg
#  extracting: Flicker8k_Dataset/3339768802_8ab768558a.jpg
#  extracting: Flicker8k_Dataset/3360930596_1e75164ce6.jpg
#  extracting: Flicker8k_Dataset/3479423813_517e93a43a.jpg
#  extracting: Flicker8k_Dataset/3516960094_87fb4889de.jpg
#  extracting: Flicker8k_Dataset/3532412342_e0a004b404.jpg
#  extracting: Flicker8k_Dataset/3587009091_37188fd07e.jpg
#  extracting: Flicker8k_Dataset/3594566537_55bd712fdb.jpg
#  extracting: Flicker8k_Dataset/3596428453_8cfdec4869.jpg
#  extracting: Flicker8k_Dataset/3619381206_5bc8b406f9.jpg
#  extracting: Flicker8k_Dataset/1434607942_da5432c28c.jpg
#  extracting: Flicker8k_Dataset/1937262236_cbf5bfa101.jpg
#  extracting: Flicker8k_Dataset/1994416869_4dd769a806.jpg
#  extracting: Flicker8k_Dataset/2281006675_fde04e93dd.jpg
#  extracting: Flicker8k_Dataset/2466420387_86fe77c966.jpg
#  extracting: Flicker8k_Dataset/2616508003_fa5ca5780d.jpg
#  extracting: Flicker8k_Dataset/2745663684_650f84e1e6.jpg
#  extracting: Flicker8k_Dataset/2792195540_af5fb95caa.jpg
#  extracting: Flicker8k_Dataset/2895700779_fac1d9d278.jpg
#  extracting: Flicker8k_Dataset/3145967309_b33abe4d84.jpg
#  extracting: Flicker8k_Dataset/3155451946_c0862c70cb.jpg
#  extracting: Flicker8k_Dataset/3183883750_b6acc40397.jpg
#  extracting: Flicker8k_Dataset/3222041930_f642f49d28.jpg
#  extracting: Flicker8k_Dataset/3266306177_7994dc2865.jpg
#  extracting: Flicker8k_Dataset/3439331800_e71e1d808f.jpg
#  extracting: Flicker8k_Dataset/3465000218_c94e54e208.jpg
#  extracting: Flicker8k_Dataset/3473534758_1ae3847781.jpg
#  extracting: Flicker8k_Dataset/3490597800_8f94f7d353.jpg
#  extracting: Flicker8k_Dataset/3497224764_6e17544e0d.jpg
#  extracting: Flicker8k_Dataset/3526897578_3cf77da99b.jpg
#  extracting: Flicker8k_Dataset/3534548254_7bee952a0e.jpg
#  extracting: Flicker8k_Dataset/3576536763_3c8c4f232e.jpg
#  extracting: Flicker8k_Dataset/3580375310_46ec3e476c.jpg
#  extracting: Flicker8k_Dataset/3599442049_e448c7c9b2.jpg
#  extracting: Flicker8k_Dataset/3681324243_b69fa90842.jpg
#  extracting: Flicker8k_Dataset/3736786640_70df13be2c.jpg
#  extracting: Flicker8k_Dataset/1479028910_3dab3448c8.jpg
#  extracting: Flicker8k_Dataset/1527333441_af65636a74.jpg
#  extracting: Flicker8k_Dataset/2075321027_c8fcbaf581.jpg
#  extracting: Flicker8k_Dataset/2084217208_7bd9bc85e5.jpg
#  extracting: Flicker8k_Dataset/2085078076_b9db242d21.jpg
#  extracting: Flicker8k_Dataset/2198494923_8159551be4.jpg
#  extracting: Flicker8k_Dataset/2252264255_03fefc25af.jpg
#  extracting: Flicker8k_Dataset/2414384480_096867d695.jpg
#  extracting: Flicker8k_Dataset/2419591925_1038c6c570.jpg
#  extracting: Flicker8k_Dataset/2444134813_20895c640c.jpg
#  extracting: Flicker8k_Dataset/2479652566_8f9fac8af5.jpg
#  extracting: Flicker8k_Dataset/2525455265_f84ba72bd7.jpg
#  extracting: Flicker8k_Dataset/2604305843_ebe3e8a328.jpg
#  extracting: Flicker8k_Dataset/2676651833_3bb42bbb32.jpg
#  extracting: Flicker8k_Dataset/2701487024_e866eb4550.jpg
#  extracting: Flicker8k_Dataset/2704379125_9c35650d16.jpg
#  extracting: Flicker8k_Dataset/2715289538_d77c8d0a85.jpg
#  extracting: Flicker8k_Dataset/2877511986_c965ced502.jpg
#  extracting: Flicker8k_Dataset/2911928620_06c3fa293e.jpg
#  extracting: Flicker8k_Dataset/3016726158_4d15b83b06.jpg
#  extracting: Flicker8k_Dataset/3030823649_3b7b6c728d.jpg
#  extracting: Flicker8k_Dataset/3053785363_50392f2c53.jpg
#  extracting: Flicker8k_Dataset/3085973779_29f44fbdaa.jpg
#  extracting: Flicker8k_Dataset/3132760860_3e743a935d.jpg
#  extracting: Flicker8k_Dataset/3135826945_f7c741e5b7.jpg
#  extracting: Flicker8k_Dataset/3222250187_ef610f267e.jpg
#  extracting: Flicker8k_Dataset/3351370405_e417e38f52.jpg
#  extracting: Flicker8k_Dataset/3399284917_721aefe2a7.jpg
#  extracting: Flicker8k_Dataset/3436074878_21515a6706.jpg
#  extracting: Flicker8k_Dataset/3710468717_c051d96a5f.jpg
#  extracting: Flicker8k_Dataset/1396064003_3fd949c9dd.jpg
#  extracting: Flicker8k_Dataset/2102030040_2e8f4738f7.jpg
#  extracting: Flicker8k_Dataset/2165461920_1a4144eb2b.jpg
#  extracting: Flicker8k_Dataset/2244613488_4d1f9edb33.jpg
#  extracting: Flicker8k_Dataset/2293424366_7b5fcd2398.jpg
#  extracting: Flicker8k_Dataset/2306674172_dc07c7f847.jpg
#  extracting: Flicker8k_Dataset/2341254813_c53a5ef27a.jpg
#  extracting: Flicker8k_Dataset/2525232298_cf42d415ab.jpg
#  extracting: Flicker8k_Dataset/2543679402_9359e1ee4e.jpg
#  extracting: Flicker8k_Dataset/2585141045_b496a7b7c4.jpg
#  extracting: Flicker8k_Dataset/2598979962_c01811cfca.jpg
#  extracting: Flicker8k_Dataset/2662537919_18a29fca8a.jpg
#  extracting: Flicker8k_Dataset/2714674623_8cd05ac114.jpg
#  extracting: Flicker8k_Dataset/2942798367_022df04b49.jpg
#  extracting: Flicker8k_Dataset/2978271431_f6a7f19825.jpg
#  extracting: Flicker8k_Dataset/3028561714_83fb921067.jpg
#  extracting: Flicker8k_Dataset/3168123064_d1983b8f92.jpg
#  extracting: Flicker8k_Dataset/3270691950_88583c3524.jpg
#  extracting: Flicker8k_Dataset/3279524184_d5e2ffbaed.jpg
#  extracting: Flicker8k_Dataset/3293945284_6a04e477a9.jpg
#  extracting: Flicker8k_Dataset/3315726723_64c9b0a945.jpg
#  extracting: Flicker8k_Dataset/3364026240_645d533fda.jpg
#  extracting: Flicker8k_Dataset/3441145615_b4fcd9eea0.jpg
#  extracting: Flicker8k_Dataset/3443326696_fe0549c5be.jpg
#  extracting: Flicker8k_Dataset/3504881781_6a842e043b.jpg
#  extracting: Flicker8k_Dataset/3527524436_a54aca78a9.jpg
#  extracting: Flicker8k_Dataset/3574627719_790325430e.jpg
#  extracting: Flicker8k_Dataset/3592992234_6d3fe58a70.jpg
#  extracting: Flicker8k_Dataset/3606909929_90a1a072b7.jpg
#  extracting: Flicker8k_Dataset/3612484827_0e479f9ee8.jpg
#  extracting: Flicker8k_Dataset/3679405397_bb130ea3c2.jpg
#  extracting: Flicker8k_Dataset/1472882567_33dc14c8b6.jpg
#  extracting: Flicker8k_Dataset/2125626631_a4b63af97e.jpg
#  extracting: Flicker8k_Dataset/2381583688_a6dd0a7279.jpg
#  extracting: Flicker8k_Dataset/2500826039_165e75b20c.jpg
#  extracting: Flicker8k_Dataset/2502856739_490db7a657.jpg
#  extracting: Flicker8k_Dataset/2574509968_e4692ae169.jpg
#  extracting: Flicker8k_Dataset/2596514158_c516e57974.jpg
#  extracting: Flicker8k_Dataset/2679926555_b11cf45595.jpg
#  extracting: Flicker8k_Dataset/2701042060_92508ea8fa.jpg
#  extracting: Flicker8k_Dataset/2831672255_d779807c14.jpg
#  extracting: Flicker8k_Dataset/2909955251_4b326a46a7.jpg
#  extracting: Flicker8k_Dataset/2995461857_dd26188dcf.jpg
#  extracting: Flicker8k_Dataset/3122497129_d08f5729b8.jpg
#  extracting: Flicker8k_Dataset/3164347907_2813f8ff0b.jpg
#  extracting: Flicker8k_Dataset/3209350613_eb86579ee8.jpg
#  extracting: Flicker8k_Dataset/3209523192_05a4cef844.jpg
#  extracting: Flicker8k_Dataset/3213622536_31da7f6682.jpg
#  extracting: Flicker8k_Dataset/3225880532_c8d5d1d798.jpg
#  extracting: Flicker8k_Dataset/3251906388_c09d44340e.jpg
#  extracting: Flicker8k_Dataset/3315353266_70f0bbb1c3.jpg
#  extracting: Flicker8k_Dataset/3365602213_dd3287a633.jpg
#  extracting: Flicker8k_Dataset/3372340429_91c4f4af30.jpg
#  extracting: Flicker8k_Dataset/3399616238_77acf4ee12.jpg
#  extracting: Flicker8k_Dataset/3429391520_930b153f94.jpg
#  extracting: Flicker8k_Dataset/3430287726_94a1825bbf.jpg
#  extracting: Flicker8k_Dataset/3457572788_e1fe4f6480.jpg
#  extracting: Flicker8k_Dataset/3532205154_5674b628ea.jpg
#  extracting: Flicker8k_Dataset/3626689571_5817f99c0e.jpg
#  extracting: Flicker8k_Dataset/3686078365_9e655e238f.jpg
#  extracting: Flicker8k_Dataset/3719461451_07de35af3a.jpg
#  extracting: Flicker8k_Dataset/1453366750_6e8cf601bf.jpg
#  extracting: Flicker8k_Dataset/1584315962_5b0b45d02d.jpg
#  extracting: Flicker8k_Dataset/2089122314_40d5739aef.jpg
#  extracting: Flicker8k_Dataset/2164363131_6930455d45.jpg
#  extracting: Flicker8k_Dataset/2252403744_148fc11f68.jpg
#  extracting: Flicker8k_Dataset/2272823323_3b7291cd47.jpg
#  extracting: Flicker8k_Dataset/2294516804_11e255807a.jpg
#  extracting: Flicker8k_Dataset/2363100645_c3423a0433.jpg
#  extracting: Flicker8k_Dataset/2522297487_57edf117f7.jpg
#  extracting: Flicker8k_Dataset/2618322793_5fb164d86a.jpg
#  extracting: Flicker8k_Dataset/2626158969_ac09aeb88d.jpg
#  extracting: Flicker8k_Dataset/2671602981_4edde92658.jpg
#  extracting: Flicker8k_Dataset/2708686056_1b8f356264.jpg
#  extracting: Flicker8k_Dataset/2710416789_555180e399.jpg
#  extracting: Flicker8k_Dataset/2726301121_95a2fbd22b.jpg
#  extracting: Flicker8k_Dataset/2911107495_e3cec16a24.jpg
#  extracting: Flicker8k_Dataset/2917843040_7c9caaaa8a.jpg
#  extracting: Flicker8k_Dataset/2982928615_06db40f4cd.jpg
#  extracting: Flicker8k_Dataset/3019923691_3b3c5a4766.jpg
#  extracting: Flicker8k_Dataset/3090957866_f1b2b7f214.jpg
#  extracting: Flicker8k_Dataset/3211316116_a2462e327d.jpg
#  extracting: Flicker8k_Dataset/3229519418_040f05ced1.jpg
#  extracting: Flicker8k_Dataset/3263141261_db3a4798b5.jpg
#  extracting: Flicker8k_Dataset/3342855466_44038a8aa3.jpg
#  extracting: Flicker8k_Dataset/3354414391_a3908bd4ff.jpg
#  extracting: Flicker8k_Dataset/3405113041_4b72c24801.jpg
#  extracting: Flicker8k_Dataset/3437147889_4cf26dd525.jpg
#  extracting: Flicker8k_Dataset/3458215674_2aa5e64643.jpg
#  extracting: Flicker8k_Dataset/3480379024_545e8ec818.jpg
#  extracting: Flicker8k_Dataset/3580741947_cc64a83648.jpg
#  extracting: Flicker8k_Dataset/3582465732_78f77f34ae.jpg
#  extracting: Flicker8k_Dataset/3613667665_1881c689ea.jpg
#  extracting: Flicker8k_Dataset/3629492654_619d7b67ee.jpg
#  extracting: Flicker8k_Dataset/3661659196_6ed90f96c0.jpg
#  extracting: Flicker8k_Dataset/3692746368_ab7d97ab31.jpg
#  extracting: Flicker8k_Dataset/1402641725_5e027ecaa7.jpg
#  extracting: Flicker8k_Dataset/1478294229_7e1c822fea.jpg
#  extracting: Flicker8k_Dataset/1569562856_eedb5a0a1f.jpg
#  extracting: Flicker8k_Dataset/1721637099_93e9ec2a2f.jpg
#  extracting: Flicker8k_Dataset/2021613437_d99731f986.jpg
#  extracting: Flicker8k_Dataset/2151300603_248a9fe715.jpg
#  extracting: Flicker8k_Dataset/2290330500_e7bdaa58e1.jpg
#  extracting: Flicker8k_Dataset/2301379282_5fbcf230d1.jpg
#  extracting: Flicker8k_Dataset/2311690895_0d6efe11c8.jpg
#  extracting: Flicker8k_Dataset/2374652725_32f90fa15c.jpg
#  extracting: Flicker8k_Dataset/2480327661_fb69829f57.jpg
#  extracting: Flicker8k_Dataset/2595102568_347f6d4b07.jpg
#  extracting: Flicker8k_Dataset/2708634088_a4686be24c.jpg
#  extracting: Flicker8k_Dataset/2800004913_c8394ba332.jpg
#  extracting: Flicker8k_Dataset/2882056260_4399dd4d7c.jpg
#  extracting: Flicker8k_Dataset/2944025729_5aecda30ee.jpg
#  extracting: Flicker8k_Dataset/2987195421_e830c59fb6.jpg
#  extracting: Flicker8k_Dataset/2998861375_02817e0147.jpg
#  extracting: Flicker8k_Dataset/3006926228_cf3c067b3e.jpg
#  extracting: Flicker8k_Dataset/3019199755_a984bc21b1.jpg
#  extracting: Flicker8k_Dataset/3041384194_04316bd416.jpg
#  extracting: Flicker8k_Dataset/3106791484_13e18c33d8.jpg
#  extracting: Flicker8k_Dataset/3109780402_dbae082dc5.jpg
#  extracting: Flicker8k_Dataset/3210359094_ee51285301.jpg
#  extracting: Flicker8k_Dataset/3221128704_d1205db79b.jpg
#  extracting: Flicker8k_Dataset/3256272547_5ae6c66293.jpg
#  extracting: Flicker8k_Dataset/3273625566_2454f1556b.jpg
#  extracting: Flicker8k_Dataset/3432550415_e7b77232de.jpg
#  extracting: Flicker8k_Dataset/3449114979_6cdc3e8da8.jpg
#  extracting: Flicker8k_Dataset/3534512991_f9fd66f165.jpg
#  extracting: Flicker8k_Dataset/3630641436_8f9ac5b9b2.jpg
#  extracting: Flicker8k_Dataset/3655074079_7df3812bc5.jpg
#  extracting: Flicker8k_Dataset/1131155939_b4b457b05e.jpg
#  extracting: Flicker8k_Dataset/1408958345_68eea9a4e4.jpg
#  extracting: Flicker8k_Dataset/1464120327_d90279ca3a.jpg
#  extracting: Flicker8k_Dataset/1573017288_4d481856e2.jpg
#  extracting: Flicker8k_Dataset/2374247382_023a86b9ca.jpg
#  extracting: Flicker8k_Dataset/2496370758_a3fbc49837.jpg
#  extracting: Flicker8k_Dataset/2591603141_33d6397e0a.jpg
#  extracting: Flicker8k_Dataset/2709359730_13bca100af.jpg
#  extracting: Flicker8k_Dataset/2721656220_5f4cda8bc1.jpg
#  extracting: Flicker8k_Dataset/2860872588_f2c7b30e1a.jpg
#  extracting: Flicker8k_Dataset/2943079526_e9033a6556.jpg
#  extracting: Flicker8k_Dataset/3006094603_c5b32d2758.jpg
#  extracting: Flicker8k_Dataset/3154693053_cfcd05c226.jpg
#  extracting: Flicker8k_Dataset/3171035252_dba286ae5c.jpg
#  extracting: Flicker8k_Dataset/3182996527_70d9c323d5.jpg
#  extracting: Flicker8k_Dataset/3185662156_c877583c53.jpg
#  extracting: Flicker8k_Dataset/3186073578_6e115f45f5.jpg
#  extracting: Flicker8k_Dataset/3241892328_4ebf8b21ce.jpg
#  extracting: Flicker8k_Dataset/3264678536_46601d25f0.jpg
#  extracting: Flicker8k_Dataset/3315616181_15dd137e27.jpg
#  extracting: Flicker8k_Dataset/3320032226_63390d74a6.jpg
#  extracting: Flicker8k_Dataset/3331525712_af1dcc47f2.jpg
#  extracting: Flicker8k_Dataset/3333039854_461329aac2.jpg
#  extracting: Flicker8k_Dataset/3348385580_10b53391f9.jpg
#  extracting: Flicker8k_Dataset/3354474353_daf9e168cf.jpg
#  extracting: Flicker8k_Dataset/3429351222_17ae744daf.jpg
#  extracting: Flicker8k_Dataset/3457364788_3514a52091.jpg
#  extracting: Flicker8k_Dataset/3552435734_04da83b905.jpg
#  extracting: Flicker8k_Dataset/3564738125_10400f69c0.jpg
#  extracting: Flicker8k_Dataset/3569406219_f37ebf7b92.jpg
#  extracting: Flicker8k_Dataset/3582914739_bef2828a06.jpg
#  extracting: Flicker8k_Dataset/1463638541_c02cfa04dc.jpg
#  extracting: Flicker8k_Dataset/1799188614_b5189728ba.jpg
#  extracting: Flicker8k_Dataset/2228167286_7089ab236a.jpg
#  extracting: Flicker8k_Dataset/2281075738_230892b241.jpg
#  extracting: Flicker8k_Dataset/2352414953_10f3cd0f1f.jpg
#  extracting: Flicker8k_Dataset/2434074318_e35a567220.jpg
#  extracting: Flicker8k_Dataset/2543017787_9720b4fa1c.jpg
#  extracting: Flicker8k_Dataset/2589156742_c46bc82137.jpg
#  extracting: Flicker8k_Dataset/2742426734_291df6da08.jpg
#  extracting: Flicker8k_Dataset/2752919987_8bfca604ab.jpg
#  extracting: Flicker8k_Dataset/2830309113_c79d7be554.jpg
#  extracting: Flicker8k_Dataset/2839932205_3c9c27cd99.jpg
#  extracting: Flicker8k_Dataset/2875583266_4da13ae12d.jpg
#  extracting: Flicker8k_Dataset/2877088081_7ca408cb25.jpg
#  extracting: Flicker8k_Dataset/2904997007_23d4b94101.jpg
#  extracting: Flicker8k_Dataset/2955673642_4279b32097.jpg
#  extracting: Flicker8k_Dataset/2991994607_06f24ec7a6.jpg
#  extracting: Flicker8k_Dataset/3056569684_c264c88d00.jpg
#  extracting: Flicker8k_Dataset/3170110692_d1e0e66cee.jpg
#  extracting: Flicker8k_Dataset/3244586044_205d5ae2ba.jpg
#  extracting: Flicker8k_Dataset/3262849619_0bc4f88ef9.jpg
#  extracting: Flicker8k_Dataset/3332467180_d72f9b067d.jpg
#  extracting: Flicker8k_Dataset/3356938707_d95ba97430.jpg
#  extracting: Flicker8k_Dataset/3368819708_0bfa0808f8.jpg
#  extracting: Flicker8k_Dataset/3372251830_baa3665928.jpg
#  extracting: Flicker8k_Dataset/3425853460_bfcd0b41f6.jpg
#  extracting: Flicker8k_Dataset/3458577912_67db47209d.jpg
#  extracting: Flicker8k_Dataset/3537474810_cf676b3259.jpg
#  extracting: Flicker8k_Dataset/3590294974_4ef98f013e.jpg
#  extracting: Flicker8k_Dataset/3601843201_4809e66909.jpg
#  extracting: Flicker8k_Dataset/3649307685_60c1294d2a.jpg
#  extracting: Flicker8k_Dataset/3703107969_175da4b276.jpg
#  extracting: Flicker8k_Dataset/1095980313_3c94799968.jpg
#  extracting: Flicker8k_Dataset/1321723162_9d4c78b8af.jpg
#  extracting: Flicker8k_Dataset/1480712062_32a61ad4b7.jpg
#  extracting: Flicker8k_Dataset/1499581619_a5f65a882c.jpg
#  extracting: Flicker8k_Dataset/2097489021_ca1b9f5c3b.jpg
#  extracting: Flicker8k_Dataset/2144846312_d4c738dc6c.jpg
#  extracting: Flicker8k_Dataset/2258662398_2797d0eca8.jpg
#  extracting: Flicker8k_Dataset/2324779494_5e72d29171.jpg
#  extracting: Flicker8k_Dataset/2331510788_986809bbb4.jpg
#  extracting: Flicker8k_Dataset/2351479551_e8820a1ff3.jpg
#  extracting: Flicker8k_Dataset/2435685480_a79d42e564.jpg
#  extracting: Flicker8k_Dataset/2510560080_1439fe32f2.jpg
#  extracting: Flicker8k_Dataset/2522230304_1581d52961.jpg
#  extracting: Flicker8k_Dataset/2660008870_b672a4c76a.jpg
#  extracting: Flicker8k_Dataset/2662816021_ac474e0fde.jpg
#  extracting: Flicker8k_Dataset/2709648336_15455e60b2.jpg
#  extracting: Flicker8k_Dataset/2921094201_2ed70a7963.jpg
#  extracting: Flicker8k_Dataset/3004291093_35d6fd8548.jpg
#  extracting: Flicker8k_Dataset/3046190891_05c6ecd9b6.jpg
#  extracting: Flicker8k_Dataset/3047264032_14393ecea8.jpg
#  extracting: Flicker8k_Dataset/3064716525_b8418d4946.jpg
#  extracting: Flicker8k_Dataset/3065560742_f6e266ccd9.jpg
#  extracting: Flicker8k_Dataset/3211577298_14296db6fd.jpg
#  extracting: Flicker8k_Dataset/3217291172_10ef70af88.jpg
#  extracting: Flicker8k_Dataset/3229898555_16877f5180.jpg
#  extracting: Flicker8k_Dataset/3268407162_6274e0f74f.jpg
#  extracting: Flicker8k_Dataset/3424424006_98f9d1921c.jpg
#  extracting: Flicker8k_Dataset/3446586125_cafa0bfd67.jpg
#  extracting: Flicker8k_Dataset/3501781809_88429e3b83.jpg
#  extracting: Flicker8k_Dataset/3532028205_9ddd7599f8.jpg
#  extracting: Flicker8k_Dataset/1169307342_e7a4685a5c.jpg
#  extracting: Flicker8k_Dataset/1287064529_aa4e4f3c31.jpg
#  extracting: Flicker8k_Dataset/1352410176_af6b139734.jpg
#  extracting: Flicker8k_Dataset/2056930414_d2b0f1395a.jpg
#  extracting: Flicker8k_Dataset/2210368267_0615754b48.jpg
#  extracting: Flicker8k_Dataset/2268596214_ca532f5c63.jpg
#  extracting: Flicker8k_Dataset/2512876666_9da03f9589.jpg
#  extracting: Flicker8k_Dataset/2682194299_92005b26c6.jpg
#  extracting: Flicker8k_Dataset/2845845721_d0bc113ff7.jpg
#  extracting: Flicker8k_Dataset/2865376471_43c5e6b941.jpg
#  extracting: Flicker8k_Dataset/3041170372_c4376cd497.jpg
#  extracting: Flicker8k_Dataset/3087485737_cb09bc80b6.jpg
#  extracting: Flicker8k_Dataset/3138399980_d6ab8b2272.jpg
#  extracting: Flicker8k_Dataset/3217910740_d1d61c08ab.jpg
#  extracting: Flicker8k_Dataset/3230132205_dccfafa5ee.jpg
#  extracting: Flicker8k_Dataset/3259222690_69737f2a6e.jpg
#  extracting: Flicker8k_Dataset/3274879561_74997bbfff.jpg
#  extracting: Flicker8k_Dataset/3371567529_606fa3452b.jpg
#  extracting: Flicker8k_Dataset/3388094307_5a83be64a5.jpg
#  extracting: Flicker8k_Dataset/3416091866_a96003d652.jpg
#  extracting: Flicker8k_Dataset/3442540072_b22ca2410f.jpg
#  extracting: Flicker8k_Dataset/3484019369_354e0b88c0.jpg
#  extracting: Flicker8k_Dataset/3613585080_36629d8157.jpg
#  extracting: Flicker8k_Dataset/3614582606_16bd88dab2.jpg
#  extracting: Flicker8k_Dataset/3616771728_2c16bf8d85.jpg
#  extracting: Flicker8k_Dataset/3618908551_7fd2de5710.jpg
#  extracting: Flicker8k_Dataset/3666188047_e81e1d97a7.jpg
#  extracting: Flicker8k_Dataset/3668518431_43abb169eb.jpg
#  extracting: Flicker8k_Dataset/3695517194_2a6b604cb2.jpg
#  extracting: Flicker8k_Dataset/3728015645_b43a60258b.jpg
#  extracting: Flicker8k_Dataset/1019604187_d087bf9a5f.jpg
#  extracting: Flicker8k_Dataset/1022454428_b6b660a67b.jpg
#  extracting: Flicker8k_Dataset/1343426964_cde3fb54e8.jpg
#  extracting: Flicker8k_Dataset/2064790732_219e52e19c.jpg
#  extracting: Flicker8k_Dataset/2101808682_0d66ef4a08.jpg
#  extracting: Flicker8k_Dataset/2157003092_eaeb977789.jpg
#  extracting: Flicker8k_Dataset/2186367337_0ce9ce2104.jpg
#  extracting: Flicker8k_Dataset/2421446839_fe7d46c177.jpg
#  extracting: Flicker8k_Dataset/2474918824_88660c7757.jpg
#  extracting: Flicker8k_Dataset/2512683710_991c9d466d.jpg
#  extracting: Flicker8k_Dataset/2600867924_cd502fc911.jpg
#  extracting: Flicker8k_Dataset/2698487246_e827404cac.jpg
#  extracting: Flicker8k_Dataset/2769605231_dae8b30201.jpg
#  extracting: Flicker8k_Dataset/2833560457_24aedf3bef.jpg
#  extracting: Flicker8k_Dataset/2876994989_a4ebbd8491.jpg
#  extracting: Flicker8k_Dataset/2882589788_cb0b407a8d.jpg
#  extracting: Flicker8k_Dataset/2884651479_12e400ee58.jpg
#  extracting: Flicker8k_Dataset/3079917032_3cfacb2fd7.jpg
#  extracting: Flicker8k_Dataset/3183195653_11b66acb34.jpg
#  extracting: Flicker8k_Dataset/3192069971_83c5a90b4c.jpg
#  extracting: Flicker8k_Dataset/3336682980_1082a66878.jpg
#  extracting: Flicker8k_Dataset/3374223949_90776ba934.jpg
#  extracting: Flicker8k_Dataset/3487419819_e3f89444ce.jpg
#  extracting: Flicker8k_Dataset/3512791890_eb065b460a.jpg
#  extracting: Flicker8k_Dataset/3648160673_0c783236a6.jpg
#  extracting: Flicker8k_Dataset/3663307538_468739e4c3.jpg
#  extracting: Flicker8k_Dataset/3697359692_8a5cdbe4fe.jpg
#  extracting: Flicker8k_Dataset/3721812313_6000566803.jpg
#  extracting: Flicker8k_Dataset/3726590391_bc6e729bb6.jpg
#  extracting: Flicker8k_Dataset/1460500597_866fa0c6f3.jpg
#  extracting: Flicker8k_Dataset/2064417101_3b9d817f4a.jpg
#  extracting: Flicker8k_Dataset/2068960566_21e85ae0dc.jpg
#  extracting: Flicker8k_Dataset/2245348304_08bc5642f1.jpg
#  extracting: Flicker8k_Dataset/2248487956_2603f55ab9.jpg
#  extracting: Flicker8k_Dataset/2290589734_b588471345.jpg
#  extracting: Flicker8k_Dataset/2318721455_80c6644441.jpg
#  extracting: Flicker8k_Dataset/2396669903_5217a83641.jpg
#  extracting: Flicker8k_Dataset/2451285022_59255e7fd9.jpg
#  extracting: Flicker8k_Dataset/2527303359_6c3dc3f282.jpg
#  extracting: Flicker8k_Dataset/2689358407_9932f1b20c.jpg
#  extracting: Flicker8k_Dataset/2734219983_fe86a60bf9.jpg
#  extracting: Flicker8k_Dataset/2764732789_1392e962d0.jpg
#  extracting: Flicker8k_Dataset/2768021570_46bc6325e3.jpg
#  extracting: Flicker8k_Dataset/2930616480_7fd45ca79b.jpg
#  extracting: Flicker8k_Dataset/2984174290_a915748d77.jpg
#  extracting: Flicker8k_Dataset/3084010872_cbc3ea8239.jpg
#  extracting: Flicker8k_Dataset/3138562460_44227a35cf.jpg
#  extracting: Flicker8k_Dataset/3149919755_f9272b10b3.jpg
#  extracting: Flicker8k_Dataset/3203908917_53e53c03d1.jpg
#  extracting: Flicker8k_Dataset/3205214191_29b42b9b09.jpg
#  extracting: Flicker8k_Dataset/3227148358_f152303584.jpg
#  extracting: Flicker8k_Dataset/3260191163_6c1551eee8.jpg
#  extracting: Flicker8k_Dataset/3278189732_f750cb26b7.jpg
#  extracting: Flicker8k_Dataset/3286761458_34af7e4499.jpg
#  extracting: Flicker8k_Dataset/3325578605_afa7f662ec.jpg
#  extracting: Flicker8k_Dataset/3407357681_5aeaab5b59.jpg
#  extracting: Flicker8k_Dataset/3425887426_bf60b8afa3.jpg
#  extracting: Flicker8k_Dataset/3535284878_f90f10236e.jpg
#  extracting: Flicker8k_Dataset/3547313700_39368b9a2f.jpg
#  extracting: Flicker8k_Dataset/3605676864_0fb491267e.jpg
#  extracting: Flicker8k_Dataset/3713177334_32f3245fd8.jpg
#  extracting: Flicker8k_Dataset/1115679311_245eff2f4b.jpg
#  extracting: Flicker8k_Dataset/1118557877_736f339752.jpg
#  extracting: Flicker8k_Dataset/1317292658_ba29330a0b.jpg
#  extracting: Flicker8k_Dataset/1417637704_572b4d6557.jpg
#  extracting: Flicker8k_Dataset/1468962616_5803b4397f.jpg
#  extracting: Flicker8k_Dataset/2280354512_c0d035d53f.jpg
#  extracting: Flicker8k_Dataset/2315418282_80bd0bb1c0.jpg
#  extracting: Flicker8k_Dataset/2330062180_355ccbceb5.jpg
#  extracting: Flicker8k_Dataset/2369840118_a1c4240ab7.jpg
#  extracting: Flicker8k_Dataset/2376694294_9a4ecc3b90.jpg
#  extracting: Flicker8k_Dataset/2407091303_931c918490.jpg
#  extracting: Flicker8k_Dataset/2458862292_466a920ee2.jpg
#  extracting: Flicker8k_Dataset/2462153092_e3f4d8f6a2.jpg
#  extracting: Flicker8k_Dataset/2531942624_c3c072064e.jpg
#  extracting: Flicker8k_Dataset/2680990587_eee6bd04fb.jpg
#  extracting: Flicker8k_Dataset/2774430374_fee1d793e7.jpg
#  extracting: Flicker8k_Dataset/2774581025_81a3074e2e.jpg
#  extracting: Flicker8k_Dataset/3181599388_68559cfc17.jpg
#  extracting: Flicker8k_Dataset/3225478803_f7a9a41a1d.jpg
#  extracting: Flicker8k_Dataset/3231880001_193a579b97.jpg
#  extracting: Flicker8k_Dataset/3436259762_43709321ff.jpg
#  extracting: Flicker8k_Dataset/3449170348_34dac4a380.jpg
#  extracting: Flicker8k_Dataset/3528966521_2e871ff6a1.jpg
#  extracting: Flicker8k_Dataset/3591457224_88281dd04f.jpg
#  extracting: Flicker8k_Dataset/3663951804_868982f3f9.jpg
#  extracting: Flicker8k_Dataset/1474474514_b3eb492722.jpg
#  extracting: Flicker8k_Dataset/1597557856_30640e0b43.jpg
#  extracting: Flicker8k_Dataset/2061354254_faa5bd294b.jpg
#  extracting: Flicker8k_Dataset/2092870249_90e3f1855b.jpg
#  extracting: Flicker8k_Dataset/2180356743_b3a3c9a7f6.jpg
#  extracting: Flicker8k_Dataset/2188688248_f57a28a5a7.jpg
#  extracting: Flicker8k_Dataset/2300920203_f29260b1db.jpg
#  extracting: Flicker8k_Dataset/2367317953_503317493e.jpg
#  extracting: Flicker8k_Dataset/2555622234_3e531e4014.jpg
#  extracting: Flicker8k_Dataset/2602306033_2b3100d36b.jpg
#  extracting: Flicker8k_Dataset/2616284322_b13e7c344e.jpg
#  extracting: Flicker8k_Dataset/2689491604_d8760f57b4.jpg
#  extracting: Flicker8k_Dataset/2766726291_b83eb5d315.jpg
#  extracting: Flicker8k_Dataset/2795866891_7559fd8422.jpg
#  extracting: Flicker8k_Dataset/2824004868_1fc0a81173.jpg
#  extracting: Flicker8k_Dataset/2860041212_797afd6ccf.jpg
#  extracting: Flicker8k_Dataset/2968216482_ede65b20a8.jpg
#  extracting: Flicker8k_Dataset/3051341320_1d0166e775.jpg
#  extracting: Flicker8k_Dataset/3157622277_9f59b4f62f.jpg
#  extracting: Flicker8k_Dataset/3282925526_535ff9f2b2.jpg
#  extracting: Flicker8k_Dataset/3285993030_87b0f1d202.jpg
#  extracting: Flicker8k_Dataset/3291587911_81fc33300e.jpg
#  extracting: Flicker8k_Dataset/3319058642_885d756295.jpg
#  extracting: Flicker8k_Dataset/3341084434_db5e7d1fdc.jpg
#  extracting: Flicker8k_Dataset/3382303178_69b6d1bdd2.jpg
#  extracting: Flicker8k_Dataset/3489774350_a94e6c7bfc.jpg
#  extracting: Flicker8k_Dataset/3497069793_2d4baf5b4b.jpg
#  extracting: Flicker8k_Dataset/3582066525_e9d6377f56.jpg
#  extracting: Flicker8k_Dataset/3584534971_b44f82c4b9.jpg
#  extracting: Flicker8k_Dataset/3625049113_554d82c2a1.jpg
#  extracting: Flicker8k_Dataset/1032122270_ea6f0beedb.jpg
#  extracting: Flicker8k_Dataset/1527297882_dededc7891.jpg
#  extracting: Flicker8k_Dataset/2086678529_b3301c2d71.jpg
#  extracting: Flicker8k_Dataset/2171576939_d1e72daab2.jpg
#  extracting: Flicker8k_Dataset/2216568822_84c295c3b0.jpg
#  extracting: Flicker8k_Dataset/2218334049_e649dbdb1a.jpg
#  extracting: Flicker8k_Dataset/2247138288_7355861203.jpg
#  extracting: Flicker8k_Dataset/2257294002_0073263c54.jpg
#  extracting: Flicker8k_Dataset/2305437797_e6c3460190.jpg
#  extracting: Flicker8k_Dataset/2317714088_bcd081f926.jpg
#  extracting: Flicker8k_Dataset/2319087586_919472310f.jpg
#  extracting: Flicker8k_Dataset/2445283938_ff477c7952.jpg
#  extracting: Flicker8k_Dataset/2460159430_71ab1aacfa.jpg
#  extracting: Flicker8k_Dataset/2695093520_5cfeb0729d.jpg
#  extracting: Flicker8k_Dataset/2718376488_3c62f7642c.jpg
#  extracting: Flicker8k_Dataset/2807209904_389d81f33a.jpg
#  extracting: Flicker8k_Dataset/2921430836_3b4d062238.jpg
#  extracting: Flicker8k_Dataset/3049770416_0fb1954315.jpg
#  extracting: Flicker8k_Dataset/3280173193_98c2d6a223.jpg
#  extracting: Flicker8k_Dataset/3337332770_5eda5cceb7.jpg
#  extracting: Flicker8k_Dataset/3337461409_e4e317853d.jpg
#  extracting: Flicker8k_Dataset/3357194782_c261bb6cbf.jpg
#  extracting: Flicker8k_Dataset/3364861247_d590fa170d.jpg
#  extracting: Flicker8k_Dataset/3464708890_3cab754998.jpg
#  extracting: Flicker8k_Dataset/3470008804_0ca36a7a09.jpg
#  extracting: Flicker8k_Dataset/3470951932_27ed74eb0b.jpg
#  extracting: Flicker8k_Dataset/3596459539_a47aa80612.jpg
#  extracting: Flicker8k_Dataset/3623331945_df0f51d7dd.jpg
#  extracting: Flicker8k_Dataset/3668259129_e073af1533.jpg
#  extracting: Flicker8k_Dataset/3673032164_6c6843de87.jpg
#  extracting: Flicker8k_Dataset/3730011219_588cdc7972.jpg
#  extracting: Flicker8k_Dataset/1406010299_5755339f08.jpg
#  extracting: Flicker8k_Dataset/1526325728_74eb4153d8.jpg
#  extracting: Flicker8k_Dataset/1569687608_0e3b3ad044.jpg
#  extracting: Flicker8k_Dataset/2136455112_202c093ba4.jpg
#  extracting: Flicker8k_Dataset/2249865945_f432c8e5da.jpg
#  extracting: Flicker8k_Dataset/2346629210_8d6668d22d.jpg
#  extracting: Flicker8k_Dataset/2754898893_95239c1f19.jpg
#  extracting: Flicker8k_Dataset/2918653119_f535fc25c4.jpg
#  extracting: Flicker8k_Dataset/2939197393_93dc64c4bb.jpg
#  extracting: Flicker8k_Dataset/3005126574_49c28ffbee.jpg
#  extracting: Flicker8k_Dataset/3016178284_ec50a09e8c.jpg
#  extracting: Flicker8k_Dataset/3033257301_e2c8a39b04.jpg
#  extracting: Flicker8k_Dataset/3081182021_22cfa18dd4.jpg
#  extracting: Flicker8k_Dataset/3096163135_584901a5ae.jpg
#  extracting: Flicker8k_Dataset/3250695024_93e8ab7305.jpg
#  extracting: Flicker8k_Dataset/3263215700_e27f81f8b9.jpg
#  extracting: Flicker8k_Dataset/3275065565_9e2a640fbc.jpg
#  extracting: Flicker8k_Dataset/3293751640_d81a6f3a0c.jpg
#  extracting: Flicker8k_Dataset/3510219078_670b6b3157.jpg
#  extracting: Flicker8k_Dataset/3534824784_7133119316.jpg
#  extracting: Flicker8k_Dataset/3538213870_9856a76b2a.jpg
#  extracting: Flicker8k_Dataset/3547704737_57d42d5d9d.jpg
#  extracting: Flicker8k_Dataset/3560891822_7d4c1e3580.jpg
#  extracting: Flicker8k_Dataset/3572267708_9d8a81d4a4.jpg
#  extracting: Flicker8k_Dataset/3595408539_a7d8aabc24.jpg
#  extracting: Flicker8k_Dataset/3613030730_0b28b079ba.jpg
#  extracting: Flicker8k_Dataset/3616525288_9c19223de6.jpg
#  extracting: Flicker8k_Dataset/1089755335_0bfbfd30e6.jpg
#  extracting: Flicker8k_Dataset/1410193619_13fff6c875.jpg
#  extracting: Flicker8k_Dataset/1501985304_8c50093004.jpg
#  extracting: Flicker8k_Dataset/2355763034_9fb61a8165.jpg
#  extracting: Flicker8k_Dataset/2451114871_8617ae2f16.jpg
#  extracting: Flicker8k_Dataset/2522809984_2e8a7df4fb.jpg
#  extracting: Flicker8k_Dataset/2556392380_ee57514233.jpg
#  extracting: Flicker8k_Dataset/2561212119_1af8cb9b5d.jpg
#  extracting: Flicker8k_Dataset/2603792708_18a97bac97.jpg
#  extracting: Flicker8k_Dataset/2666179615_f05a9d8331.jpg
#  extracting: Flicker8k_Dataset/2855667597_bf6ceaef8e.jpg
#  extracting: Flicker8k_Dataset/2985439112_8a3b77d5c9.jpg
#  extracting: Flicker8k_Dataset/2999162229_80d17099b6.jpg
#  extracting: Flicker8k_Dataset/3026102616_3cf350af9e.jpg
#  extracting: Flicker8k_Dataset/3069216757_c419b3898e.jpg
#  extracting: Flicker8k_Dataset/3170802797_3c851bb475.jpg
#  extracting: Flicker8k_Dataset/3223302125_f8154417f4.jpg
#  extracting: Flicker8k_Dataset/3234375022_1464ea7f8a.jpg
#  extracting: Flicker8k_Dataset/3282897060_8c584e2ce8.jpg
#  extracting: Flicker8k_Dataset/3287969199_08e775d896.jpg
#  extracting: Flicker8k_Dataset/3310551665_15b79ef4ea.jpg
#  extracting: Flicker8k_Dataset/3325910784_5ecb88310c.jpg
#  extracting: Flicker8k_Dataset/3375134059_7e9eb2ef01.jpg
#  extracting: Flicker8k_Dataset/3392851587_a638ff25e2.jpg
#  extracting: Flicker8k_Dataset/3523474077_16e14bc54c.jpg
#  extracting: Flicker8k_Dataset/3525841965_7814484515.jpg
#  extracting: Flicker8k_Dataset/3591094476_b61acd63d6.jpg
#  extracting: Flicker8k_Dataset/3673878924_506c9d767b.jpg
#  extracting: Flicker8k_Dataset/3738789925_7d17dbdf25.jpg
#  extracting: Flicker8k_Dataset/1105959054_9c3a738096.jpg
#  extracting: Flicker8k_Dataset/1234817607_924893f6e1.jpg
#  extracting: Flicker8k_Dataset/1539166395_0cdc0accee.jpg
#  extracting: Flicker8k_Dataset/2241768909_3d96d48417.jpg
#  extracting: Flicker8k_Dataset/2346189044_546ed84aa9.jpg
#  extracting: Flicker8k_Dataset/2431723485_bc6b8e6418.jpg
#  extracting: Flicker8k_Dataset/2600170955_bf30c5d5c0.jpg
#  extracting: Flicker8k_Dataset/2629295654_59ea1472a1.jpg
#  extracting: Flicker8k_Dataset/3091594712_2166604334.jpg
#  extracting: Flicker8k_Dataset/3106340185_80d0cb770a.jpg
#  extracting: Flicker8k_Dataset/3143159297_6f2f663ea6.jpg
#  extracting: Flicker8k_Dataset/3197482764_2f289cb726.jpg
#  extracting: Flicker8k_Dataset/3215896272_e9b4b547a9.jpg
#  extracting: Flicker8k_Dataset/3258391809_38fc6211f7.jpg
#  extracting: Flicker8k_Dataset/3259160693_067ec7ebc3.jpg
#  extracting: Flicker8k_Dataset/3259992164_94600858b3.jpg
#  extracting: Flicker8k_Dataset/3386953179_84c2d7922f.jpg
#  extracting: Flicker8k_Dataset/3396275223_ee080df8b5.jpg
#  extracting: Flicker8k_Dataset/3418504074_083f0bb68d.jpg
#  extracting: Flicker8k_Dataset/3453544202_3855ab34b6.jpg
#  extracting: Flicker8k_Dataset/3520936130_9e90872560.jpg
#  extracting: Flicker8k_Dataset/3534668485_6887629ff0.jpg
#  extracting: Flicker8k_Dataset/3562169000_6aa7f1043d.jpg
#  extracting: Flicker8k_Dataset/3578841731_f775cab089.jpg
#  extracting: Flicker8k_Dataset/3604383863_5e387cb8e6.jpg
#  extracting: Flicker8k_Dataset/3604384383_db6805d1b9.jpg
#  extracting: Flicker8k_Dataset/3620343911_64a862904e.jpg
#  extracting: Flicker8k_Dataset/3668900592_a84b0c07db.jpg
#  extracting: Flicker8k_Dataset/3720366614_dfa8fe1088.jpg
#  extracting: Flicker8k_Dataset/3729405438_6e79077ab2.jpg
#  extracting: Flicker8k_Dataset/1298866571_b4c496b71c.jpg
#  extracting: Flicker8k_Dataset/1332815795_8eea44375e.jpg
#  extracting: Flicker8k_Dataset/1346051107_9cdc14e070.jpg
#  extracting: Flicker8k_Dataset/2050067751_22d2763fd2.jpg
#  extracting: Flicker8k_Dataset/2135502491_a15c6b5eae.jpg
#  extracting: Flicker8k_Dataset/2504991916_dc61e59e49.jpg
#  extracting: Flicker8k_Dataset/2591455200_2319651f2f.jpg
#  extracting: Flicker8k_Dataset/2631625732_75b714e685.jpg
#  extracting: Flicker8k_Dataset/2642475077_69d19deb74.jpg
#  extracting: Flicker8k_Dataset/2674784195_704f6b79d0.jpg
#  extracting: Flicker8k_Dataset/2755053974_5cc157512e.jpg
#  extracting: Flicker8k_Dataset/2842609837_b3a0b383f7.jpg
#  extracting: Flicker8k_Dataset/2982881046_45765ced2c.jpg
#  extracting: Flicker8k_Dataset/3090386315_87ed417814.jpg
#  extracting: Flicker8k_Dataset/3091912922_0d6ebc8f6a.jpg
#  extracting: Flicker8k_Dataset/3126681108_f88128699c.jpg
#  extracting: Flicker8k_Dataset/3150315970_8f045c41a4.jpg
#  extracting: Flicker8k_Dataset/3186412658_2ab2ebd397.jpg
#  extracting: Flicker8k_Dataset/3222496967_45d468ee66.jpg
#  extracting: Flicker8k_Dataset/3248220732_0f173fc197.jpg
#  extracting: Flicker8k_Dataset/3268443910_b36dbc1e5c.jpg
#  extracting: Flicker8k_Dataset/3299418821_21531b5b3c.jpg
#  extracting: Flicker8k_Dataset/3323498985_fd9d2803fd.jpg
#  extracting: Flicker8k_Dataset/3335375223_b4da8df523.jpg
#  extracting: Flicker8k_Dataset/3339105374_cc41e0b7d7.jpg
#  extracting: Flicker8k_Dataset/3463922449_f6040a2931.jpg
#  extracting: Flicker8k_Dataset/3547600292_6f8aac7f2e.jpg
#  extracting: Flicker8k_Dataset/3634400263_c6fcaa48e1.jpg
#  extracting: Flicker8k_Dataset/3665179773_dd217416fc.jpg
#  extracting: Flicker8k_Dataset/3704698586_a42c25d0c1.jpg
#  extracting: Flicker8k_Dataset/1536774449_e16b1b6382.jpg
#  extracting: Flicker8k_Dataset/2510029990_7014f907cb.jpg
#  extracting: Flicker8k_Dataset/2521213787_ca9b5a1758.jpg
#  extracting: Flicker8k_Dataset/2521938720_911ac092f7.jpg
#  extracting: Flicker8k_Dataset/2622624460_207dbcc4cf.jpg
#  extracting: Flicker8k_Dataset/2635400219_2e1a984fd3.jpg
#  extracting: Flicker8k_Dataset/2665904080_8a3b9639d5.jpg
#  extracting: Flicker8k_Dataset/2786299623_a3c48bd318.jpg
#  extracting: Flicker8k_Dataset/2815788792_d226215d10.jpg
#  extracting: Flicker8k_Dataset/2904129133_e6ae5a1ec6.jpg
#  extracting: Flicker8k_Dataset/3098714492_19939e3b19.jpg
#  extracting: Flicker8k_Dataset/3106883334_419f3fb16f.jpg
#  extracting: Flicker8k_Dataset/3121482932_f77ca12c01.jpg
#  extracting: Flicker8k_Dataset/3146232740_df3da0163b.jpg
#  extracting: Flicker8k_Dataset/3367053761_8ec5834bf3.jpg
#  extracting: Flicker8k_Dataset/3377344932_6dfce93248.jpg
#  extracting: Flicker8k_Dataset/3457460673_800d7f7dd9.jpg
#  extracting: Flicker8k_Dataset/3487131146_9d3aca387a.jpg
#  extracting: Flicker8k_Dataset/3510695264_ef460fa6cc.jpg
#  extracting: Flicker8k_Dataset/3532782283_341f0381a3.jpg
#  extracting: Flicker8k_Dataset/3549997413_01388dece0.jpg
#  extracting: Flicker8k_Dataset/3571039224_b34fa2f94c.jpg
#  extracting: Flicker8k_Dataset/3576259024_9c05b163aa.jpg
#  extracting: Flicker8k_Dataset/3638688673_176f99d7fd.jpg
#  extracting: Flicker8k_Dataset/3639547922_0b00fed5cd.jpg
#  extracting: Flicker8k_Dataset/3733074526_82aa8d5f8d.jpg
#  extracting: Flicker8k_Dataset/1394599090_fe0ba238f0.jpg
#  extracting: Flicker8k_Dataset/2207244634_1db1a1890b.jpg
#  extracting: Flicker8k_Dataset/2552949275_b8cdc450cc.jpg
#  extracting: Flicker8k_Dataset/2616643090_4f2d2d1a44.jpg
#  extracting: Flicker8k_Dataset/2643309379_2cde08516c.jpg
#  extracting: Flicker8k_Dataset/2648310638_d6c576b5e4.jpg
#  extracting: Flicker8k_Dataset/2831215155_07ba8f1805.jpg
#  extracting: Flicker8k_Dataset/2843695880_eeea6c67db.jpg
#  extracting: Flicker8k_Dataset/2901880865_3fd7b66a45.jpg
#  extracting: Flicker8k_Dataset/2944836001_b38b516286.jpg
#  extracting: Flicker8k_Dataset/3072114570_e1c0127529.jpg
#  extracting: Flicker8k_Dataset/3158327361_6f1a518228.jpg
#  extracting: Flicker8k_Dataset/3189293145_35dea42679.jpg
#  extracting: Flicker8k_Dataset/3203707977_cc9448fecb.jpg
#  extracting: Flicker8k_Dataset/3220650628_4ed964e5b4.jpg
#  extracting: Flicker8k_Dataset/3225226381_9fe306fb9e.jpg
#  extracting: Flicker8k_Dataset/3241965735_8742782a70.jpg
#  extracting: Flicker8k_Dataset/3245266444_2e798096e6.jpg
#  extracting: Flicker8k_Dataset/3264397357_72f084cac1.jpg
#  extracting: Flicker8k_Dataset/3336374196_f6eaca542f.jpg
#  extracting: Flicker8k_Dataset/3367851138_757d6bd2ef.jpg
#  extracting: Flicker8k_Dataset/3388330419_85d72f7cda.jpg
#  extracting: Flicker8k_Dataset/3412450683_7da035f2de.jpg
#  extracting: Flicker8k_Dataset/3416339125_0860d3d1eb.jpg
#  extracting: Flicker8k_Dataset/3540155303_08225a4567.jpg
#  extracting: Flicker8k_Dataset/3549614763_42f34f3d1e.jpg
#  extracting: Flicker8k_Dataset/3631344685_ed0f3e091b.jpg
#  extracting: Flicker8k_Dataset/3649384501_f1e06c58c0.jpg
#  extracting: Flicker8k_Dataset/3697379772_40d831392b.jpg
#  extracting: Flicker8k_Dataset/3704431444_f337ec2b90.jpg
#  extracting: Flicker8k_Dataset/1439282131_3814d6ae04.jpg
#  extracting: Flicker8k_Dataset/1445754124_647168f211.jpg
#  extracting: Flicker8k_Dataset/1517340899_ee1c74a8f6.jpg
#  extracting: Flicker8k_Dataset/2087317114_cf06df5aa5.jpg
#  extracting: Flicker8k_Dataset/2256320794_0286c31bfa.jpg
#  extracting: Flicker8k_Dataset/2261169495_98254e2e66.jpg
#  extracting: Flicker8k_Dataset/2423550887_ffc9bbcf71.jpg
#  extracting: Flicker8k_Dataset/2424398046_1a55c71376.jpg
#  extracting: Flicker8k_Dataset/2573141440_28a762d537.jpg
#  extracting: Flicker8k_Dataset/2667549961_57e5e2c0a5.jpg
#  extracting: Flicker8k_Dataset/2831656774_36982aafdb.jpg
#  extracting: Flicker8k_Dataset/2836864045_9a093cfd65.jpg
#  extracting: Flicker8k_Dataset/2866254827_9a8f592017.jpg
#  extracting: Flicker8k_Dataset/2892467862_52a3c67418.jpg
#  extracting: Flicker8k_Dataset/2918769188_565dd48060.jpg
#  extracting: Flicker8k_Dataset/2991771557_d98fa0a69f.jpg
#  extracting: Flicker8k_Dataset/3068407619_5207b26986.jpg
#  extracting: Flicker8k_Dataset/3091916691_b1c96669c6.jpg
#  extracting: Flicker8k_Dataset/3155501473_510f9c9f6b.jpg
#  extracting: Flicker8k_Dataset/3185371756_ff4e9fa8a6.jpg
#  extracting: Flicker8k_Dataset/3376942201_2c45d99237.jpg
#  extracting: Flicker8k_Dataset/3392293702_ccb0599857.jpg
#  extracting: Flicker8k_Dataset/3420278866_1d17c12713.jpg
#  extracting: Flicker8k_Dataset/3467219837_7d62213dec.jpg
#  extracting: Flicker8k_Dataset/3477712686_8428614c75.jpg
#  extracting: Flicker8k_Dataset/3482879314_d3387e95b1.jpg
#  extracting: Flicker8k_Dataset/3533484468_0787830d49.jpg
# ...
#  extracting: Flicker8k_Dataset/1478268555_7e301fc510.jpg
#  extracting: Flicker8k_Dataset/1574401950_6bedc0d29b.jpg
#  extracting: Flicker8k_Dataset/2229179070_dc8ea8582e.jpg
#  extracting: Flicker8k_Dataset/2432038587_5e4148e277.jpg
#  extracting: Flicker8k_Dataset/2470519275_65725fd38d.jpg
#  extracting: Flicker8k_Dataset/2553550034_5901aa9d6c.jpg
#  extracting: Flicker8k_Dataset/2706430695_3b5667741c.jpg
#  extracting: Flicker8k_Dataset/3091580843_178042c50b.jpg
#  extracting: Flicker8k_Dataset/3217240672_b99a682026.jpg
#  extracting: Flicker8k_Dataset/3526805681_38461c0d5d.jpg
#  extracting: Flicker8k_Dataset/3538527033_df13112d51.jpg
#  extracting: Flicker8k_Dataset/3593222804_c187808ac3.jpg
#  extracting: Flicker8k_Dataset/3634785801_4b23184a06.jpg
#  extracting: Flicker8k_Dataset/1523984678_edd68464da.jpg
#  extracting: Flicker8k_Dataset/1561658940_a947f2446a.jpg
#  extracting: Flicker8k_Dataset/1643915227_9f48068772.jpg
#  extracting: Flicker8k_Dataset/2689163361_4939875be5.jpg
#  extracting: Flicker8k_Dataset/2782480767_064c95eff2.jpg
#  extracting: Flicker8k_Dataset/2862004252_53894bb28b.jpg
#  extracting: Flicker8k_Dataset/2959500257_3621429a37.jpg
#  extracting: Flicker8k_Dataset/3396817186_b299ee0531.jpg
#  extracting: Flicker8k_Dataset/3431121650_056db85987.jpg
#  extracting: Flicker8k_Dataset/3547524138_4157f660b0.jpg
#  extracting: Flicker8k_Dataset/3639845565_be547c38ba.jpg
#  extracting: Flicker8k_Dataset/3649802021_8a689bc153.jpg
#  extracting: Flicker8k_Dataset/3682277595_55f8b16975.jpg
#  extracting: Flicker8k_Dataset/1307635496_94442dc21a.jpg
#  extracting: Flicker8k_Dataset/2356664078_4b1e6e465d.jpg
#  extracting: Flicker8k_Dataset/2363006088_b3e3aa5c0b.jpg
#  extracting: Flicker8k_Dataset/2366421102_2d60d53a0e.jpg
#  extracting: Flicker8k_Dataset/2559638792_a803ff63d1.jpg
#  extracting: Flicker8k_Dataset/2562483332_eb791a3ce5.jpg
#  extracting: Flicker8k_Dataset/2633082074_32c85f532c.jpg
#  extracting: Flicker8k_Dataset/2837908308_8bc25c6b02.jpg
#  extracting: Flicker8k_Dataset/3024022266_3528c16ed8.jpg
#  extracting: Flicker8k_Dataset/3163273640_8d3ef22eaf.jpg
#  extracting: Flicker8k_Dataset/3477369101_8e0c61d8f4.jpg
#  extracting: Flicker8k_Dataset/3533145793_5d69f72e41.jpg
#  extracting: Flicker8k_Dataset/3595992258_6f192e6ae7.jpg
#  extracting: Flicker8k_Dataset/3646970605_d25c25340b.jpg
#  extracting: Flicker8k_Dataset/3654338683_13b2f95a9a.jpg
#  extracting: Flicker8k_Dataset/3667822570_d39850e217.jpg
#  extracting: Flicker8k_Dataset/1428641354_f7453afbea.jpg
#  extracting: Flicker8k_Dataset/2469620360_6c620c6f35.jpg
#  extracting: Flicker8k_Dataset/2479553749_f7ac031940.jpg
#  extracting: Flicker8k_Dataset/2581066814_179d28f306.jpg
#  extracting: Flicker8k_Dataset/2636876892_9353521a1c.jpg
#  extracting: Flicker8k_Dataset/2718024196_3ff660416a.jpg
#  extracting: Flicker8k_Dataset/2802337003_56e555cd30.jpg
#  extracting: Flicker8k_Dataset/2846843520_b0e6211478.jpg
#  extracting: Flicker8k_Dataset/2878705136_609dfbf318.jpg
#  extracting: Flicker8k_Dataset/2937697444_2367ff0e28.jpg
#  extracting: Flicker8k_Dataset/3053743109_a2d780c0d2.jpg
#  extracting: Flicker8k_Dataset/3415589320_71a5bf64cf.jpg
#  extracting: Flicker8k_Dataset/3436063693_15c8d377a2.jpg
#  extracting: Flicker8k_Dataset/3638577494_fe55f7b4cb.jpg
#  extracting: Flicker8k_Dataset/3686924335_3c51e8834a.jpg
#  extracting: Flicker8k_Dataset/1095590286_c654f7e5a9.jpg
#  extracting: Flicker8k_Dataset/2137071442_1c9658c81a.jpg
#  extracting: Flicker8k_Dataset/2268115375_69884e958d.jpg
#  extracting: Flicker8k_Dataset/2466171100_5e60cfcc11.jpg
#  extracting: Flicker8k_Dataset/2506892928_7e79bec613.jpg
#  extracting: Flicker8k_Dataset/2577972703_a22c5f2a87.jpg
#  extracting: Flicker8k_Dataset/2588625139_fdf6610218.jpg
#  extracting: Flicker8k_Dataset/2704257993_d485058a5f.jpg
#  extracting: Flicker8k_Dataset/2766630484_ce73f47031.jpg
#  extracting: Flicker8k_Dataset/3048821353_83d4c0cbb9.jpg
#  extracting: Flicker8k_Dataset/3386893620_5f0bb4e794.jpg
#  extracting: Flicker8k_Dataset/3576060775_d9121519cc.jpg
#  extracting: Flicker8k_Dataset/3724150944_fc62e8d5e0.jpg
#  extracting: Flicker8k_Dataset/1808504612_3508f3c9bb.jpg
#  extracting: Flicker8k_Dataset/2203615439_3c7cdc39dc.jpg
#  extracting: Flicker8k_Dataset/2314732154_83bc7f7314.jpg
#  extracting: Flicker8k_Dataset/2560278143_aa5110aa37.jpg
#  extracting: Flicker8k_Dataset/2737609659_efce872c24.jpg
#  extracting: Flicker8k_Dataset/2981372647_2061278c60.jpg
#  extracting: Flicker8k_Dataset/3070713991_8696796937.jpg
#  extracting: Flicker8k_Dataset/3454988449_1de1ef4f20.jpg
#  extracting: Flicker8k_Dataset/3664297064_a4d45cbbbc.jpg
#  extracting: Flicker8k_Dataset/3716277216_c04002be81.jpg
#  extracting: Flicker8k_Dataset/1476241331_2f43b67aed.jpg
#  extracting: Flicker8k_Dataset/1810651611_35aae644fb.jpg
#  extracting: Flicker8k_Dataset/2522467011_cc825d89ac.jpg
#  extracting: Flicker8k_Dataset/2527163162_d0fb802992.jpg
#  extracting: Flicker8k_Dataset/2553024095_735bc46267.jpg
#  extracting: Flicker8k_Dataset/2808870080_4ea4f3327e.jpg
#  extracting: Flicker8k_Dataset/2911238432_33ec2d8cec.jpg
#  extracting: Flicker8k_Dataset/3186527735_6e9fe2cf88.jpg
#  extracting: Flicker8k_Dataset/3204525212_d548c7fca7.jpg
#  extracting: Flicker8k_Dataset/3273325447_81c94000da.jpg
#  extracting: Flicker8k_Dataset/3533775651_9d7e93dacf.jpg
#  extracting: Flicker8k_Dataset/3547368652_0d85c665d3.jpg
#  extracting: Flicker8k_Dataset/1337792872_d01a390b33.jpg
#  extracting: Flicker8k_Dataset/1801188148_a176954965.jpg
#  extracting: Flicker8k_Dataset/2113530024_5bc6a90e42.jpg
#  extracting: Flicker8k_Dataset/2218907190_5f43bf5e4d.jpg
#  extracting: Flicker8k_Dataset/2233426944_0959835ced.jpg
#  extracting: Flicker8k_Dataset/2448210587_9fe7ea5f42.jpg
#  extracting: Flicker8k_Dataset/2624457062_89efc497a8.jpg
#  extracting: Flicker8k_Dataset/2763601657_09a52a063f.jpg
#  extracting: Flicker8k_Dataset/2848571082_26454cb981.jpg
#  extracting: Flicker8k_Dataset/2888658480_e922a3dec2.jpg
#  extracting: Flicker8k_Dataset/3030294889_78b2ccbe51.jpg
#  extracting: Flicker8k_Dataset/3109688427_d2e702456c.jpg
#  extracting: Flicker8k_Dataset/3568197730_a071d7595b.jpg
#  extracting: Flicker8k_Dataset/3609999845_faf5d2fe74.jpg
#  extracting: Flicker8k_Dataset/1176580356_9810d877bf.jpg
#  extracting: Flicker8k_Dataset/2071309418_1d7580b0f0.jpg
#  extracting: Flicker8k_Dataset/2337919839_df83827fa0.jpg
#  extracting: Flicker8k_Dataset/2367139509_1ee4530b28.jpg
#  extracting: Flicker8k_Dataset/2391812384_7429b5e567.jpg
#  extracting: Flicker8k_Dataset/2399551242_c62a46dd5f.jpg
#  extracting: Flicker8k_Dataset/2495394666_2ef6c37519.jpg
#  extracting: Flicker8k_Dataset/2757779501_c41c86a595.jpg
#  extracting: Flicker8k_Dataset/2892413015_5ecd9d972a.jpg
#  extracting: Flicker8k_Dataset/3014546644_d53db746ec.jpg
#  extracting: Flicker8k_Dataset/3036033157_522a43a550.jpg
#  extracting: Flicker8k_Dataset/3277162496_dff7eeb59e.jpg
#  extracting: Flicker8k_Dataset/3640870001_acbd1d5ceb.jpg
#  extracting: Flicker8k_Dataset/1446053356_a924b4893f.jpg
#  extracting: Flicker8k_Dataset/2125454445_5c5c4bf906.jpg
#  extracting: Flicker8k_Dataset/2255266906_8222af18b9.jpg
#  extracting: Flicker8k_Dataset/2276314067_7ee246f859.jpg
#  extracting: Flicker8k_Dataset/2384147448_c1869070d3.jpg
#  extracting: Flicker8k_Dataset/2436398074_8737f40869.jpg
#  extracting: Flicker8k_Dataset/2707873672_15e6b5d54b.jpg
#  extracting: Flicker8k_Dataset/2856456013_335297f587.jpg
#  extracting: Flicker8k_Dataset/3330935489_9cb67ca36b.jpg
#  extracting: Flicker8k_Dataset/3428038648_993a453f9e.jpg
#  extracting: Flicker8k_Dataset/3475005101_6f6e437459.jpg
#  extracting: Flicker8k_Dataset/3516521516_9950340b96.jpg
#  extracting: Flicker8k_Dataset/3585598356_8ce815bbb9.jpg
#  extracting: Flicker8k_Dataset/3615730936_23457575e9.jpg
#  extracting: Flicker8k_Dataset/3672109677_8caa992671.jpg
#  extracting: Flicker8k_Dataset/3690348036_a01f243fb0.jpg
#  extracting: Flicker8k_Dataset/1478606153_a7163bf899.jpg
#  extracting: Flicker8k_Dataset/1858963639_4588cd4be9.jpg
#  extracting: Flicker8k_Dataset/2173677067_9d0732bcc2.jpg
#  extracting: Flicker8k_Dataset/2280525192_81911f2b00.jpg
#  extracting: Flicker8k_Dataset/2589241160_3832440850.jpg
#  extracting: Flicker8k_Dataset/2857473929_4f52662c30.jpg
#  extracting: Flicker8k_Dataset/2857558098_98e9249284.jpg
#  extracting: Flicker8k_Dataset/3075068274_2a28a5263b.jpg
#  extracting: Flicker8k_Dataset/3110018626_307a123b59.jpg
#  extracting: Flicker8k_Dataset/3156113206_53c2a7b5d8.jpg
#  extracting: Flicker8k_Dataset/3174156702_95a1cda2d9.jpg
#  extracting: Flicker8k_Dataset/3238951136_2a99f1a1a8.jpg
#  extracting: Flicker8k_Dataset/3251648670_9339943ba2.jpg
#  extracting: Flicker8k_Dataset/3556037801_3992ce6826.jpg
#  extracting: Flicker8k_Dataset/3613955682_3860e116cf.jpg
#  extracting: Flicker8k_Dataset/1361420539_e9599c60ae.jpg
#  extracting: Flicker8k_Dataset/1405221276_21634dcd58.jpg
#  extracting: Flicker8k_Dataset/2619454551_c4bb726a85.jpg
#  extracting: Flicker8k_Dataset/2866820467_ae699235a7.jpg
#  extracting: Flicker8k_Dataset/3072172967_630e9c69d0.jpg
#  extracting: Flicker8k_Dataset/3342271377_446ffc34c0.jpg
#  extracting: Flicker8k_Dataset/3381392182_db2c42430e.jpg
#  extracting: Flicker8k_Dataset/3419916411_72934edcdb.jpg
#  extracting: Flicker8k_Dataset/3422394336_e465f60b7c.jpg
#  extracting: Flicker8k_Dataset/3425573919_409d9e15b2.jpg
#  extracting: Flicker8k_Dataset/3530502404_f8c3a3f61c.jpg
#  extracting: Flicker8k_Dataset/3629664676_36bcefe6b7.jpg
#  extracting: Flicker8k_Dataset/3670075789_92ea9a183a.jpg
#  extracting: Flicker8k_Dataset/1141739219_2c47195e4c.jpg
#  extracting: Flicker8k_Dataset/1269470943_ba7fc49b4d.jpg
#  extracting: Flicker8k_Dataset/1424775129_ffea9c13ab.jpg
#  extracting: Flicker8k_Dataset/1479679558_d0a01bc62b.jpg
#  extracting: Flicker8k_Dataset/1679565118_d36f0d6d52.jpg
#  extracting: Flicker8k_Dataset/2429212017_77fc107699.jpg
#  extracting: Flicker8k_Dataset/2589308405_e208b5e745.jpg
#  extracting: Flicker8k_Dataset/2607462776_78e639d891.jpg
#  extracting: Flicker8k_Dataset/2888732432_7e907a3df1.jpg
#  extracting: Flicker8k_Dataset/2972864304_481aeffe50.jpg
#  extracting: Flicker8k_Dataset/3301822808_f2ccff86f4.jpg
#  extracting: Flicker8k_Dataset/3621623690_0095e330bc.jpg
#  extracting: Flicker8k_Dataset/3737539561_d1dc161040.jpg
#  extracting: Flicker8k_Dataset/1514957266_a19827c538.jpg
#  extracting: Flicker8k_Dataset/2081141788_38fa84ce3c.jpg
#  extracting: Flicker8k_Dataset/2402462857_7684848704.jpg
#  extracting: Flicker8k_Dataset/2449289139_08fc1092c1.jpg
#  extracting: Flicker8k_Dataset/2656688132_d93be870e0.jpg
#  extracting: Flicker8k_Dataset/2967549094_d32422eb01.jpg
#  extracting: Flicker8k_Dataset/3014015906_fdba461f36.jpg
#  extracting: Flicker8k_Dataset/3453019315_cfd5c10dae.jpg
#  extracting: Flicker8k_Dataset/3640417354_b0b3e4aec9.jpg
#  extracting: Flicker8k_Dataset/3640422448_a0f42e4559.jpg
#  extracting: Flicker8k_Dataset/3670907052_c827593564.jpg
#  extracting: Flicker8k_Dataset/3718305988_fe2c91fd44.jpg
#  extracting: Flicker8k_Dataset/1067180831_a59dc64344.jpg
#  extracting: Flicker8k_Dataset/1472249944_d887c3aeda.jpg
#  extracting: Flicker8k_Dataset/2308256827_3c0a7d514d.jpg
#  extracting: Flicker8k_Dataset/2505360288_c972bd29c4.jpg
#  extracting: Flicker8k_Dataset/2687539673_d54a8dc613.jpg
#  extracting: Flicker8k_Dataset/2696866120_254a0345bc.jpg
#  extracting: Flicker8k_Dataset/2730938963_c4ed3e2258.jpg
#  extracting: Flicker8k_Dataset/2759211664_d21393b668.jpg
#  extracting: Flicker8k_Dataset/2772084628_c0ae29d87a.jpg
#  extracting: Flicker8k_Dataset/2850719435_221f15e951.jpg
#  extracting: Flicker8k_Dataset/2925577165_b83d31a7f6.jpg
#  extracting: Flicker8k_Dataset/2935703360_4f794f7f09.jpg
#  extracting: Flicker8k_Dataset/3029715635_43ab414dfb.jpg
#  extracting: Flicker8k_Dataset/3304556387_203b9d4db0.jpg
#  extracting: Flicker8k_Dataset/3667318593_fa1816b346.jpg
#  extracting: Flicker8k_Dataset/2289096282_4ef120f189.jpg
#  extracting: Flicker8k_Dataset/2607130765_97833d6ce1.jpg
#  extracting: Flicker8k_Dataset/2629334536_11f2d49e05.jpg
#  extracting: Flicker8k_Dataset/2692635048_16c279ff9e.jpg
#  extracting: Flicker8k_Dataset/3025549604_38b86198f5.jpg
#  extracting: Flicker8k_Dataset/3074842262_62b1b2168c.jpg
#  extracting: Flicker8k_Dataset/3228960484_9aab98b91a.jpg
#  extracting: Flicker8k_Dataset/3331009729_d3b14738e6.jpg
#  extracting: Flicker8k_Dataset/3349308309_92cff519f3.jpg
#  extracting: Flicker8k_Dataset/3415646718_f9f4e23a66.jpg
#  extracting: Flicker8k_Dataset/3677693858_62f2f3163f.jpg
#  extracting: Flicker8k_Dataset/1378557186_4bd1da6834.jpg
#  extracting: Flicker8k_Dataset/1449625950_fc9a8d02d9.jpg
#  extracting: Flicker8k_Dataset/1679557684_50a206e4a9.jpg
#  extracting: Flicker8k_Dataset/1931690777_897a7d8ab6.jpg
#  extracting: Flicker8k_Dataset/2306186887_0bd8ed3792.jpg
#  extracting: Flicker8k_Dataset/2519594430_551225e5bd.jpg
#  extracting: Flicker8k_Dataset/2976155358_b4dd4407cf.jpg
#  extracting: Flicker8k_Dataset/2999730677_0cfa1c146e.jpg
#  extracting: Flicker8k_Dataset/3150659152_2ace03690b.jpg
#  extracting: Flicker8k_Dataset/3541962817_78bcd3835b.jpg
#  extracting: Flicker8k_Dataset/1019077836_6fc9b15408.jpg
#  extracting: Flicker8k_Dataset/2620113705_a8fa89b8f6.jpg
#  extracting: Flicker8k_Dataset/2665264979_df9c284bf8.jpg
#  extracting: Flicker8k_Dataset/2681215810_00b0642f7b.jpg
#  extracting: Flicker8k_Dataset/2788628994_61123c03d2.jpg
#  extracting: Flicker8k_Dataset/2929006980_9f9f8f3d21.jpg
#  extracting: Flicker8k_Dataset/2934801096_230ae78d7e.jpg
#  extracting: Flicker8k_Dataset/3144705706_391d7b77c7.jpg
#  extracting: Flicker8k_Dataset/3300679815_2c6c2301cb.jpg
#  extracting: Flicker8k_Dataset/3449718979_e987c64e2d.jpg
#  extracting: Flicker8k_Dataset/3694991841_141804da1f.jpg
#  extracting: Flicker8k_Dataset/3713133789_f05e8daffd.jpg
#  extracting: Flicker8k_Dataset/3715469645_6d1dc019b3.jpg
#  extracting: Flicker8k_Dataset/1403414927_5f80281505.jpg
#  extracting: Flicker8k_Dataset/2198964806_c57b0534d3.jpg
#  extracting: Flicker8k_Dataset/2364394224_c17b09e035.jpg
#  extracting: Flicker8k_Dataset/2473293833_78820d2eaa.jpg
#  extracting: Flicker8k_Dataset/2594336381_a93772823b.jpg
#  extracting: Flicker8k_Dataset/2784625888_71a421e171.jpg
#  extracting: Flicker8k_Dataset/2836360729_6500249fe6.jpg
#  extracting: Flicker8k_Dataset/3256603992_67312b5a36.jpg
#  extracting: Flicker8k_Dataset/3264337159_e1680a35ba.jpg
#  extracting: Flicker8k_Dataset/3542771548_fcb8fa0cba.jpg
#  extracting: Flicker8k_Dataset/3618115051_41b5a7706c.jpg
#  extracting: Flicker8k_Dataset/1460352062_d64fb633e0.jpg
#  extracting: Flicker8k_Dataset/1814086703_33390d5fc7.jpg
#  extracting: Flicker8k_Dataset/2226534154_cbcab7ba32.jpg
#  extracting: Flicker8k_Dataset/3179336562_c3d0c0a3bd.jpg
#  extracting: Flicker8k_Dataset/3605061440_1d08c80a57.jpg
#  extracting: Flicker8k_Dataset/3677964239_6406ed096f.jpg
#  extracting: Flicker8k_Dataset/2508249781_36e9282423.jpg
#  extracting: Flicker8k_Dataset/2949014128_0d96196261.jpg
#  extracting: Flicker8k_Dataset/3262475923_f1f77fcd9f.jpg
#  extracting: Flicker8k_Dataset/3515451715_ac5ac04efa.jpg
#  extracting: Flicker8k_Dataset/3535372414_4c51c86fc4.jpg
#  extracting: Flicker8k_Dataset/3696698390_989f1488e7.jpg
#  extracting: Flicker8k_Dataset/3758175529_81941e7cc9.jpg
#  extracting: Flicker8k_Dataset/1926129518_4350f4f552.jpg
#  extracting: Flicker8k_Dataset/2067362863_59577f9d4d.jpg
#  extracting: Flicker8k_Dataset/2142232919_c857a09dd7.jpg
#  extracting: Flicker8k_Dataset/2273038287_3004a72a34.jpg
#  extracting: Flicker8k_Dataset/2345984157_724823b1e4.jpg
#  extracting: Flicker8k_Dataset/2994104606_bc2df6c1f4.jpg
#  extracting: Flicker8k_Dataset/3251646144_d9f4ccca3f.jpg
#  extracting: Flicker8k_Dataset/3393446245_37dd3f3b59.jpg
#  extracting: Flicker8k_Dataset/3708839890_ed448012cf.jpg
#
# 1 archive had fatal errors.

# %%
IMAGE_PATH="/content/Flicker8k_Dataset"
IMAGE_SIZE=(299,299)
VOCAB_SIZE=10000
SEQ_LENGTH=25
EMBD_DIM=512
FFT_DIM=512
BATCH_SIZE=64
EPOCHS=5
AUTOTUNE=tf.data.AUTOTUNE

# %%
def load_captions(filename):
  with open(filename) as caption:
    caption_data=caption.readlines()
    caption_mapping={}
    text_data=[]
    images_skip=set()
    for line in caption_data:
      line=line.rstrip("\n")
      line=line.split("\t")

      image_name,caption=line
      image_name=image_name.split('#')[0]
      image_name=os.path.join(IMAGE_PATH,image_name.strip())
      token=caption.strip().split()


      if len(token)<5 or len(token)>SEQ_LENGTH:
        images_skip.add(image_name)
        continue
      if image_name.endswith("jpg") and image_name not in images_skip:
        caption ="" + caption.strip() +""
        text_data.append(caption)

        if image_name in caption_mapping:
          caption_mapping[image_name].append(caption)
        else:
          caption_mapping[image_name]=[caption]

    for image_name in images_skip:
      if image_name in caption_mapping:
        del caption_mapping[image_name]
    return caption_mapping, text_data
def train_val(caption_data,train_size=0.7,shuffle=True):
    all_images = list(caption_data.keys())

      # 2. Shuffle if necessary
    if shuffle:
          np.random.shuffle(all_images)

      # 3. Split into training and validation sets
    train_size = int(len(caption_data) * train_size)

    training_data = {
          image_name: caption_data[image_name] for image_name in all_images[:train_size]
      }
    validation_data = {
          image_name: caption_data[image_name] for image_name in all_images[train_size:]
      }

      # 4. Return the splits
    return training_data, validation_data


# Load the dataset
captions_mapping, text_data = load_captions("/content/Flickr8k_text/Flickr8k.token.txt")

# Split the dataset into training and validation sets
train_data, valid_data = train_val(captions_mapping)
print("Number of training samples: ", len(train_data))
print("Number of validation samples: ", len(valid_data))
# Out:
# Number of training samples:  5350
# Number of validation samples:  2293

# %%
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


strip_chars = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
strip_chars = strip_chars.replace("<", "")
strip_chars = strip_chars.replace(">", "")

vectorization = TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=SEQ_LENGTH,
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

# Data augmentation for image data
image_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.2),
        layers.RandomContrast(0.3),
    ]
)

# %%
def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img


def process_input(img_path, captions):
    return decode_and_resize(img_path), vectorization(captions)


def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, captions))
    dataset = dataset.shuffle(BATCH_SIZE * 8)
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

    return dataset
train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))

valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))

# %%
def get_cnn_model():
    base_model = efficientnet.EfficientNetB0(
        input_shape=(*IMAGE_SIZE, 3),
        include_top=False,
        weights="imagenet",
    )

    base_model.trainable = False
    base_model_out = base_model.output
    base_model_out = layers.Reshape((-1, base_model_out.shape[-1]))(base_model_out)
    cnn_model = keras.models.Model(base_model.input, base_model_out)
    return cnn_model


class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.0
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.dense_1 = layers.Dense(embed_dim, activation="relu")

    def call(self, inputs, training, mask=None):
        inputs = self.layernorm_1(inputs)
        inputs = self.dense_1(inputs)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=None,
            training=training,
        )
        out_1 = self.layernorm_2(inputs + attention_output_1)
        return out_1


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.embed_scale = tf.math.sqrt(tf.cast(embed_dim, tf.float32))

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_tokens = embedded_tokens * self.embed_scale
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoderBlock(layers.Layer):
    def __init__(self, embed_dim, ff_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.ffn_layer_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_layer_2 = layers.Dense(embed_dim)

        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()

        self.embedding = PositionalEmbedding(
            embed_dim=EMBD_DIM,
            sequence_length=SEQ_LENGTH,
            vocab_size=VOCAB_SIZE,
        )
        self.out = layers.Dense(VOCAB_SIZE, activation="softmax")

        self.dropout_1 = layers.Dropout(0.3)
        self.dropout_2 = layers.Dropout(0.5)
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, training, mask=None):
        inputs = self.embedding(inputs)
        causal_mask = self.get_causal_attention_mask(inputs)

        if mask is not None:
            padding_mask = tf.cast(mask[:, :, tf.newaxis], dtype=tf.int32)
            combined_mask = tf.cast(mask[:, tf.newaxis, :], dtype=tf.int32)
            combined_mask = tf.minimum(combined_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=combined_mask,
            training=training,
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
            training=training,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        ffn_out = self.ffn_layer_1(out_2)
        ffn_out = self.dropout_1(ffn_out, training=training)
        ffn_out = self.ffn_layer_2(ffn_out)

        ffn_out = self.layernorm_3(ffn_out + out_2, training=training)
        ffn_out = self.dropout_2(ffn_out, training=training)
        preds = self.out(ffn_out)
        return preds

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [
                tf.expand_dims(batch_size, -1),
                tf.constant([1, 1], dtype=tf.int32),
            ],
            axis=0,
        )
        return tf.tile(mask, mult)


class ImageCaptioningModel(keras.Model):
    def __init__(
        self,
        cnn_model,
        encoder,
        decoder,
        num_captions_per_image=5,
        image_aug=None,
    ):
        super().__init__()
        self.cnn_model = cnn_model
        self.encoder = encoder
        self.decoder = decoder
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.acc_tracker = keras.metrics.Mean(name="accuracy")
        self.num_captions_per_image = num_captions_per_image
        self.image_aug = image_aug

    def calculate_loss(self, y_true, y_pred, mask):
        loss = self.loss(y_true, y_pred)
        mask = tf.cast(mask, dtype=loss.dtype)
        loss *= mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

    def calculate_accuracy(self, y_true, y_pred, mask):
        accuracy = tf.equal(y_true, tf.argmax(y_pred, axis=2))
        accuracy = tf.math.logical_and(mask, accuracy)
        accuracy = tf.cast(accuracy, dtype=tf.float32)
        mask = tf.cast(mask, dtype=tf.float32)
        return tf.reduce_sum(accuracy) / tf.reduce_sum(mask)

    def _compute_caption_loss_and_acc(self, img_embed, batch_seq, training=True):
        encoder_out = self.encoder(img_embed, training=training)
        batch_seq_inp = batch_seq[:, :-1]
        batch_seq_true = batch_seq[:, 1:]
        mask = tf.math.not_equal(batch_seq_true, 0)
        batch_seq_pred = self.decoder(
            batch_seq_inp, encoder_out, training=training, mask=mask
        )
        loss = self.calculate_loss(batch_seq_true, batch_seq_pred, mask)
        acc = self.calculate_accuracy(batch_seq_true, batch_seq_pred, mask)
        return loss, acc

    def train_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        if self.image_aug:
            batch_img = self.image_aug(batch_img)


        img_embed = self.cnn_model(batch_img)


        for i in range(self.num_captions_per_image):
            with tf.GradientTape() as tape:
                loss, acc = self._compute_caption_loss_and_acc(
                    img_embed, batch_seq[:, i, :], training=True
                )

                # 3. Update loss and accuracy
                batch_loss += loss
                batch_acc += acc

            # 4. Get the list of all the trainable weights
            train_vars = (
                self.encoder.trainable_variables + self.decoder.trainable_variables
            )

            # 5. Get the gradients
            grads = tape.gradient(loss, train_vars)

            # 6. Update the trainable weights
            self.optimizer.apply_gradients(zip(grads, train_vars))

        # 7. Update the trackers
        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 8. Return the loss and accuracy values
        return {
            "loss": self.loss_tracker.result(),
            "acc": self.acc_tracker.result(),
        }

    def test_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            loss, acc = self._compute_caption_loss_and_acc(
                img_embed, batch_seq[:, i, :], training=False
            )

            # 3. Update batch loss and batch accuracy
            batch_loss += loss
            batch_acc += acc

        batch_acc /= float(self.num_captions_per_image)

        # 4. Update the trackers
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 5. Return the loss and accuracy values
        return {
            "loss": self.loss_tracker.result(),
            "acc": self.acc_tracker.result(),
        }

    @property
    def metrics(self):
        # We need to list our metrics here so the `reset_states()` can be
        # called automatically.
        return [self.loss_tracker, self.acc_tracker]


cnn_model = get_cnn_model()
encoder = TransformerEncoderBlock(embed_dim=EMBD_DIM, dense_dim=FFT_DIM, num_heads=1)
decoder = TransformerDecoderBlock(embed_dim=EMBD_DIM, ff_dim=FFT_DIM, num_heads=2)
caption_model = ImageCaptioningModel(
    cnn_model=cnn_model,
    encoder=encoder,
    decoder=decoder,
    image_aug=image_augmentation,
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
cross_entropy = keras.losses.SparseCategoricalCrossentropy(
    from_logits=False,
    reduction="sum", # Changed reduction to 'sum'
)

# EarlyStopping criteria
early_stopping = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)


# Learning Rate Scheduler for the optimizer
class LRSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, post_warmup_learning_rate, warmup_steps):
        super().__init__()
        self.post_warmup_learning_rate = post_warmup_learning_rate
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        global_step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        warmup_progress = global_step / warmup_steps
        warmup_learning_rate = self.post_warmup_learning_rate * warmup_progress
        return tf.cond(
            global_step < warmup_steps,
            lambda: warmup_learning_rate,
            lambda: self.post_warmup_learning_rate,
        )


# Create a learning rate schedule
num_train_steps = len(train_dataset) * EPOCHS
num_warmup_steps = num_train_steps // 15
lr_schedule = LRSchedule(post_warmup_learning_rate=1e-4, warmup_steps=num_warmup_steps)

# Compile the model
caption_model.compile(optimizer=keras.optimizers.Adam(lr_schedule), loss=cross_entropy)

# Fit the model
caption_model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=valid_dataset,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/5
# 84/84 [==============================] - 373s 4s/step - loss: 17466.6250 - acc: 0.1101 - val_loss: 13912.9160 - val_acc: 0.2449
# Epoch 2/5
# 84/84 [==============================] - 346s 4s/step - loss: 13246.4180 - acc: 0.2543 - val_loss: 12460.0879 - val_acc: 0.2833
# Epoch 3/5
# 84/84 [==============================] - 345s 4s/step - loss: 12024.3135 - acc: 0.2913 - val_loss: 11708.9521 - val_acc: 0.3077
# Epoch 4/5
# 84/84 [==============================] - 342s 4s/step - loss: 11234.8770 - acc: 0.3161 - val_loss: 11239.0000 - val_acc: 0.3225
# Epoch 5/5
# 84/84 [==============================] - 343s 4s/step - loss: 10657.3770 - acc: 0.3338 - val_loss: 10941.1572 - val_acc: 0.3333

# %%
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
max_decoded_sentence_length = SEQ_LENGTH - 1
valid_images = list(valid_data.keys())


def generate_caption():
    # Select a random image from the validation dataset
    sample_img = np.random.choice(valid_images)

    # Read the image from the disk
    sample_img = decode_and_resize(sample_img)
    img = sample_img.numpy().clip(0, 255).astype(np.uint8)
    plt.imshow(img)
    plt.show()

    # Pass the image to the CNN
    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)

    # Pass the image features to the Transformer encoder
    encoded_img = caption_model.encoder(img, training=False)

    # Generate the caption using the Transformer decoder
    decoded_caption = " "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(
            tokenized_caption, encoded_img, training=False, mask=mask
        )
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup[sampled_token_index]
        if sampled_token == "":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace(" ", "")
    decoded_caption = decoded_caption.replace(" ", "").strip()
    print("Predicted Caption: ", decoded_caption)


# Check predictions for a few samples
generate_caption()
generate_caption()
generate_caption()
# Out:
# Predicted Caption:  andandandandbasketballwhilebasketballbasketballbasketballbasketballbasketballbasketballbasketballbasketballbasketballplayerplayerplayerplayerplayerplayerplayerplayerplayer
# Predicted Caption:  andandgrassingrassgrassgrassgrassofgrassgrassingrassgrassgrassbackgroundbackgroundtreesbackgroundbackgroundtreestreeswoodsarea
# Predicted Caption:  andwithandonwateronwaterwaterwaterongrasswaterwaterongrassgrassgrasswaterwateringrassgrassbackgroundbackground
